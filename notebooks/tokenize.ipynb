# %%
from typing import Generator, List
import pickle

from gensim.models import Phrases
from gensim.models.phrases import Phraser
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
import spacy
from spacy.lang.en import English

# %%
with open(r"C:/Users/chiruco/Desktop/python/ProyPython/SentimentalAnalysis/SentimentalAnalysis/data/interim/review_classes.pkl", "rb") as input_file:
    review_classes = pickle.load(input_file)

# %%
review_classes
# Out:
# {'POS': ["This is one of the best hotels I've ever stayed at with incredible staff catering to your every need. I felt like family whilst I was there!   I stayed for 3 weeks during the pandemic and was so impressed with all the measures the hotel have put in place to keep everyone safe and well. They give you a box of masks, gloves and a bottle of hand sanitiser upon arrival, all the staff wear masks and gloves and the rooms and everything else are cleaned to the highest standard.  Plus the prices they've been offering during this time are incredible value for money! Definitely would recommend and hope to be back once travel reopens.   Thank you so much for looking after me so well until I could return home!",
#   'Everything about this hotel was awesome. The staff made me feel welcomed from the minute i arrived until the day i departed. The view from the dining area with the mountains in the background was spectacular. The grounds were manicured to perfection with flowering plants in every direction. In the center of the pool / courtyard area was the largest bougainvillea i have ever seen. It was blue and in full bloom. I estimate it was 40 feet plus in height.  Fresh flower arrangements in the reception and dining area. The room was well appointed, clean, and comfortable. I travel extensively for business and pleasure. This in one of the best hotels i have ever stayed at, truly an amazing experience. The city of Antigua is beautiful, with a grand plaza, preserved buildings and churches',
#   'Our tour group stayed here for two nights.  The view in the picture is exactly like the one I took with my own camera!!  Our room was spacious...had a fireplace....water provided in their "jug" container.  It was very clean, staff was very friendly and hospitable.',
#   'Excellent service at Porta Hotel Antigua. From the WhatsApp service I used prior to arrival to Juan Mateo going above and beyond for us at reception, the staff are incredible. The hotel is lovely, nicely appointed with a spa, gym, pools, restaurant, client parking, kids club (I’m told)...it’s an oasis amidst the bustling quaint town of Antigua. Very relaxing, we feel pampered and don’t want to leave!',
#   'I almost always stay at Hotel Antigua when I travel to Guatemala. The rooms are very clean, the staff are gracious, the pool is wonderful and the spa is amazing. I had 2 massages with Marlin on this trip and she is an outstanding massage therapist. So kind, warm, loving and in tune to your needs and preferences. I never want to leave when I stay at Hotel Antigua',
#   'I got a reservation here using my rewards points and boy am I glad I did it. The front desk staff was very helpful and guided me to the places that are of interest. Even helped me take some of my stuff to the room when she didn’t have to. She also helped organize my shuttle back to Guate Airport. I got a king-sized bed with a balcony that overlooks the arch and street. Excellent place and was quiet at night so you can rest. Price was excellent for the services rendered. ',
#   "This is a small bed and breakfast hotel, with 5 beautiful, clean and nicely decorated rooms.  The upstairs has a beautiful and comfortable patio which is very accomodating for relaxing during afternoons or evenings, the staff is the best I've ever experienced in that they're truly interested in ensuring your stay is perfect, and they want you to come back and stay with them again in Antigua. The breakfast each morning is awesome - all i can say is call Casa Del Arco first when staying in Antigua as it's close to everywhere, including the town square.",
#   "Casa del Arco is a very conveniently located bed and breakfast place in Antigua Guatemala. It's just two minute walking distance from Parque Central and the Arch of Catalina. In fact given its central location, just about every attraction in the town is accessible by walk. The place is a cosy nook with few rooms. That said, you can almost have their little lounge to yourself when you want. The rooms are tastefully done with Guatemalan textile and clean. The bed was comfortable as well. The only issue I had was the lack of ventilation. The room window opened to the steps just besides the room that would compromise my privacy but as I had mentioned, there are few rooms and very less people in the property so it was fine. The highlight of the place is the breakfast cooked by the",
#   'This place is amazing!! The staff is friendly, a good breakfast is included, and the rooms are clean and comfortable. The view from the balcony overlooks the street, and on a clear day volcanos Fuego and Acatenango. The only downfall is because of the central location, there can be some late night revelers. I hope to stay here again when I come back to Antigua!',
#   "// Overall Experience I stayed with my family of 5 for four nights and we loved our stay! The staff are so friendly and helpful. Since most of our tours were early in the morning, we missed breakfast three out of the four nights, but each morning they prepared a simple breakfast (ham & cheese sandwich, fruits & OJ) to-go so that we wouldn't go hungry. Very accommodating and flexible.  // Amenities - Airport shuttle service ($10/person), available both to and from the airport. They can also arrange transportation to other cities if you ask in advance. - Wonderful outdoor terrace upstairs, especially in the early mornings and evenings when the weather is cool. - Simple breakfast & purified water - Great location (close to tourist hotspots)  Overall, would highly recommend!",
#   'Stayed here 3 nights in May. Cute place, very small and quiet. 2 blocks from the central square, but restaurants, shops, churches, etc are all around you. Good value also. Love that breakfast is included.',
#   'A neat little hotel fairly close to the action. Have stayed here more than once. Nice enough rooms, good breakfast choices, and a great staff. Karla and her crew will do all they can to make you happy. ',
#   'My wife and I, along with 13 others in our group, stayed a total of three nights in Hotel Palacio Chico 1940--not to be confused with Hotel Palacio Chico 1850 which is a totally different hotel. Our group members were completely satisfied with their stay. The service was exceptionally accommodating. Since our three nights occurred over a period of 10 days while we volunteered and visited in other cities, they allowed us to store extra luggage between our stays. The rooms are a bit tight but the beds are comfortable. Some rooms have one bed, others have two, and some have a private bath and some shared. We preferred the two bed private bath option. It s a small hotel, with possibly ten to 15 rooms maximum. The included breakfast was satisfactory with fresh fruit and toast. Also',
#   'Very clean It is really a wonderful place where I recommand sleeping. The rooms! are cleans, beds perfects and the people in very friendly.  Nb breakfast including is very good. It is offer in the night room. In fact  nothing negative. I recommand',
#   'Best SPA, attention 10/10. Amazing food and experience!! 100% recommended. Massages are great, rooms are clean and location is great. Definitely going to come back! If you want to have the whole Antigua experience don’t hesitate to choose this hotel.',
#   'The Hotel Casa del Parque is a genuinely friendly and an interesting hotel very close to the cathedral and main square. Rosa and Alejandra are fabulous on reception and all the staff are smiley and helpful.  There is a good sized plunge pool and breakfasts are ordered on the day, if you want them. Totally unpretentious the staff have a genuine desire to ensure your stay is memorable.  ',
#   'This hostel is super clean, super cute and super located. Me and my boyfriend were sleeping in a dorm (6 beds), which was totally fine for that price (85Q). Breakfast is included! It’s sooo yummy and really fresh, don’t miss it! It’s so nice getting such an awesome breakfast while sitting at that beautiful green terrace watching the volcano „Fuego“. The cleaning-/breakfast-ladies are really friendly, they even make your bed every morning and they clean the bathrooms/showers perfectly. Thank you for your absolutely wonderful work! The girls at reception are always helpful and friendly, thank you guys! So all in all I can highly recommend this hostel for people who like cute and clean hostels with a family-atmosphere and who are NOT looking for a party hostel. Julia & Max',
#   'We stayed at the Yellow House Hostel before our Acatenago trek and after returning from Lake Atitlan. They were extremely responsive and helpful via email prior to our arrival. The girls at reception were lovely and friendly and gave good restaurant and cafe recommendations. Yellow House was lovely and clean. The bathrooms are constantly cleaned throughout the day. The showers are nice and hot.  There is a lovely breakfast included in the rate. We would definitely stay here again!',
#   'We stayed here for 3 nice in a double bed room with shared bathroom. The hosts and the staff are very friendly and helpful. The room was clean and the breakfast delicious. OMG .. The pancakes....! They have a nice and relaxing roof top to chill. Nice view. Central located. ',
#   'The staff is so great. Booked all our shuttles with them and they have other tours as well. The hostel is very clean.  The breakfast is huge and varied and you can eat it on the roof terrace overlooking three volcanoes.  This is not a party hostel, good for couples or those trying to relax.  Nice hammocks on the roof terrace.  We did laundry with them for Q5 per pound and it was back the same day.',
#   'The Santo Domingo provided the perfect locale for our 55th wedding anniversary.  The variety of food was unsurpassed, as was the ambience and service.  Suggest a mid-week stay as the hotel , and restaurants are packed on the weekends.  Be sure to tour the entire facility and unrestored areas.',
#   'Spent 1 night because of a Academic Forum .  Location is very convenient . Architecture  is unique and food is excellent as well as their staff in helping in anyway . I left cheese in the minibar refrigerator and  since I was coming back to pick up my loggage  , just with a phone call staff inmediately took care of it .   I order room service for breakfast and was willing to pay for it even though that our expenses covered the breakfast at the restaurante. They did not charge for taking my breakfast to the room .   Other activities that we had in the hotel  , where excepcional since they have gorgeous outdoor spaces  . I recommend Santo Domingo not only as a tourist but to have Seminars or forums because they have the capacity in managing small and big groups. ',
#   "Outstanding experience with one small exception. The lady who took credit card at our table in the restaurant was unfriendly and brusque. The restaurant on top of the mountain was a divine experience all the way around.  The hotel was the best I've ever stayed in and the grounds, museums, pool, and art were fabulous beyond my expectations. We were very pleased and will try to return next year to do it again. The only complaint is minor and just needed to be mentioned to someone.The location of the hotel seemed safe and secure and the room was excellent. ",
#   'This was our first stay here, and it is a beautiful property. The grounds are lovely, and our room was well appointed and very very clean (be sure to get one with a window, patio or balcony). Be sure to take advantage of visiting the onsite museums and ruins.  The staff is very very friendly and service oriented. Food was good, but they need some more "casual" options at dinner. The property was expensive by Guatemala standards, but coming from the US, affordable luxury.  We also visited the restaurant and museum at Santo Domingo del Cerro, up the hill from the hotel and had a delicious breakfast and enjoyed wonderful art installations. ',
#   "This small but beautiful hotel was home for 3 nights while we were in Antigua. It is located very conveniently close to the famous yellow Arch in Antigua and just down one block from the town square, shopping, banking and restaurants. You can't tell from the outside, but this small hotel has a beautiful courtyard with blooming plants, greenery and a pool. There is also a covered breakfast area that became our gathering place in the morning mostly because they had free coffee and cold water. Fortunately, our room was upstairs above the breakfast area. Even though there are stairs to haul your suitcases up and down, try to reserve room 10, 11 or 12. Those rooms have a balcony that you can watch Volcano Fuego erupt every night! There are several benches to sit on along the room",
#   'Our room for 2 was on the second floor.  Huge, actually 2 rooms.  Nicely furnished  .  No A/C but a ceiling fan that cooled the room very well.  Staff super, spoke English. Have a breakfast that is $6.  Made to order, and was worth 2-3 x the price.  Let them book you ride to the airport and also tours.. They are cheaper than on TripAdvisor  Located 20 yards from the central park, and easy walking distance to all the sights. These is a excellent pool..',
#   "It's a very nice Resort with Great Food and Beautiful Scenery in the Mountains close to the City of Guatemala and not too far from the Many Volcano' there. The Rooms come with a Kitchen area and a nice view outside your windows...  There are many tours we took but there were many that we didn't have Time for! Have Fun,    PK",
#   'We very much enjoyed our stay through a timeshare exchange. We had a 1 bedroom with a kitchen. The rooms were clean and comfortable with a king bed in the bedroom and fireplace, and sofa bed in living room. Kitchen was stove top burners only, no oven, but we made plenty of breakfasts and snacks no problem.  They give you two bottles of water per day and I easily purchased more to use for cooking or brushing teeth etc, we had no issues as we stuck to bottled water. We ate at the restaurant a couple times, good food nice staff. We walked into town many times, it’s not far. It’s very walkable unless you have mobility issues, the cobblestone and high sidewalks in town would be tough if you have any kind of mobility issue, but the hotel does provide an hourly shuttle until 6 pm. We',
#   'The hotel is next to La Antigua Guatemala. A shuttle service helps guests to get to the center, very  conveniently. But be aware that it works until 18h00. The rooms are excellent, the view on the volcano from the is just a dream.',
#   'Hotel was good with a good restaurant and breakfast. Two pools to be enjoyed, spa and gym and also tennis courts. Walking distance to Antigua and also a shuttle bus during daytime. Lovely views of the surrounding vulcanos.',
#   'Our mission team stayed two nights.  It was a great. The front desk staff, Gabriela and Mecedes, were the best! So helpful and friendly.  The rooms were clean and comfortable.  The price was reasonable. The location was excellent, easy walking distance from Central Park, great restaurants, shopping and beautiful old churches.  The breakfast buffet was top notch and inexpensive.  Thank you!',
#   "Very cute hotel. I really enjoyed the colors and gardens. So close to everything. The room was small but functional - we didn't need much since we were out and about! Highly recommend and look forward to coming back!",
#   'I stayed at the Hotel Casa from February 27 - 28 and March 3-4th. Upon arrival I noticed the magnificent garden and all it’s beautiful flowers.  The staff was very welcoming.  They do a lot of business with my company often so they already knew to have certain accommodations in place. The location is perfect. Two blocks close to the Arch, a few blocks close to Central Park and best a bunch of restaurants. Breakfast was delicious. Overall, I had a good stay. One suggestion.... Leave a night light at the entrance. My flight was at 6am so I had to leave at 4am. I was in room #18. I had to use the flashlight on my phone to find my way to the front.',
#   'This hotel is unique! The rooms are nice, clean, spacious but what really stands out is the staff. Always helpful and willing to go above and beyond. Location is a must for me when I travel and this beautiful hotel is located in the heart of Antigua.',
#   'We stayed at this hotel for 12 nights while studying our nearby Spanish language school, Ixchel (which we also recommend). Everything was clean and neat. Very nice security. The administration was helpful and available by text all the time. It was wonderful to have a full kitchen and washer/dryer during our stay. The apartment was perfect for our stay. It is a little off the beaten track so was quieter than the center of town but easy waking distance to everything.',
#   'The apartment is located within walking distance to various attractions, restaurants and the happening places in Antigua. The apartment is beautifully decorated, and the cherry on the cake was a bunch of fresh flowers and a huge bowl of local fruits on the dining table. Very comfortable bed, bath and kitchenette. The washing machine and dryer are a blessing, after one has been travelling through the Peten jungles. There is ample parking for your vehicle and security at the front gate. All-in-all, a perfect stay.',
#   'Different people like different things. For me the Marques is perfect.  Those of you who have been to Antigua already know that sometimes places are not easy to find.  When I stay here I know that I only need go to Central Park to find the street - no turns to remember.  When you are there get out and explore, there are so many places to see and you should not feel you have "seen" Antigua by just going to two churchs, a ruin and a market.   I don\'t always want to go out for breakfast, or dinner for that matter - and the Marques has a well equipped (with modern appliances!) kitchen so I can make meals or heat up my leftovers  if I want to, units also have a washer and dryer so I can do laundry. I always have a fire, you can purchase wood from them or buy some in the market.  TIP:',
#   'we stayed for 2 days, went to lake atitlan for the weekend and then came back for a whole week here. Really do love Antigua. Place was great! Clean, had breakfast(fresh made) delivered every day. Would definitely return and recomend. The staff was always very pleasant and helpful. Thank you!',
#   'the staff is pretty kind in all ways!  rooms are wide and beautiful, very useful kitchen and tables, also the bed-couch only a little bit too far from the parks and stuff but totally worth it highly recommend!',
#   'This hotel is beautifully laid out aroun a Central garden and small pool The rooms were very good and the service was helpful and friendly Breakfasts were excellent but let down when a buffet repacked table service, although you could still order particular items if you insisted About 20-25 ins walk to the centre of town',
#   'I have stayed at Meson de Maria for the past 10 years every time I am in Antigua. They treat me like family. The rooms are gorgeous, the service wonderful and I appreciate all the extras. They give you tea and cake at 4PM and a very good buffet breakfast in the morning. It is well located 2 blocks from the center of Antigua.',
#   'I was recommended to stay here by a friend. I was ever so happy that I did. What a lovely place in the city. It is a secure location. They close the doors at 6:30 in the evening I believe. Then you have to knock to get inside. This is not a bad deal for anyone staying there. The room was spacious and comfortable. I was on the second floor so if you have a heavy bag this could be a little difficult. The room had a comfortable bed, tv, bathroom, and a great view. The whole hotel area is a big garden. They also include breakfast, which is a perk. Eggs, beans, cheese, bread, and coffee for a delicious breakfast.',
#   'I recently stayed at the Villa Colonial Hotel during a work conference. This colonial style hotel is very well taken care of. The rooms are nice and clean, the bathrooms are comfortable and the ambiance overall is great. The food is good although the restaurant could benefit from offering more choices. My stay overall was very enjoyable.',
#   "What a nice place for a stay!  Great restaurant, good food.  Beautiful views of a volcano from a very comfortable balcony off the restaurant.  Wonderful service and really good staff herding a bunch of people around. The gardens are beautiful and extensive.  Lots of seating areas in with the flowers.  The colors are so bright through out you almost need sunglasses.  If I have one complaint it's the same complaint I have when I travel and use hotels.  The showers need a handrail or a grip of sometype as you move from wet to dry and vice versa..",
#   'The building is nice and staff friendly The room we had was facing the patio and therefore quiet We had breakfast and dinner there and the food was verry good Since it was buffet there was a big food veriaty of food including local food The only disadvantage we found was deposit boxes in the room and not enough near the reception. Pool is verry small',
#   'I have stayed at Meson de Maria over 20 times and have taken groups and everyone always agrees it is a home away from home!  The staff are always willing to go above and beyond with anything needed, the hotel is clean and the breakfast is fabulous!  The view from the rooftop terrace is unbeatable!  I highly recommend the hotel!',
#   'Set around a courtyard over two floors with a great rooftop view of Fuego. The room was clean and plenty big enough but not huge and very peaceful. Breakfast is served in the courtyard, which is a great way to start the day and all of the staff are helpful and friendly. Located just a short walk away from all the main sites and although on a busy road it is very quiet in the hotel. Would highly recommend.',
#   "On arrival into Meson de Maria, it felt rustic and old. This adds to the style however as the rooms are wonderful and filled with character (ours even had a little show fireplace)   2 blocks from the main plaza and with very helpful staff (Nery was very attentive) I'd recommend choosing this hotel if you are in Antigua.   Breakfast was a little limited , but enough to get you through to lunch. Everyone was friendly.   The rooms were clean as was the hotel , and there is a rooftop view of Antigua where you can see Fuego spewing lava at night.   Really enjoyed our stay here. Stayed 6th to 8th of March ",
#   'Lovely quaint "hotel", more like a glorified bed and breakfast. It is a very large "old" house transformed into a "hotel".  It is probably a 3 to 3.5 star small "hotel", rustic, with a great location in the middle of town, close to all must see sites. Breakfast was very limited (scrambled egss, beans and one type of white cheese). But good value ',
#   'Great hotel with a beautiful flowered courtyard for breakfast or relaxing.  A short walk from the Central Plaza and most attractions. The neighborhood was quiet. Extremely helpful staff.  While most of the staff spoke little English the manager who was present each day was fluent.  The manager gave us information on tours and shops.  Breakfast was relatively simple but good.  Our room was not very large but was well outfitted and the bed was comfortable.  We had no issues with hot water (there was plenty).Ask for a second floor room, they have  view of Fuego ( an active volcano).   There were no negatives during our 4 night stay.  The hotel is a bargain.  We would stay there again. Stop for diner and music at the Santa Clara Cafe only a block away.',
#   'We were very happy with the Casa Noble. In fact we booked it for our return to Antigua. The staff were excellent, the breakfasts were very good as well as the location. The hotel is maybe 6 blocks from the Central Park. The room was very large, clean and had a good bathroom with lots of hot water. The hotel is in a old colonial building with a very nice garden. The rooms and lounge are decorated with antique style furniture. ',
#   "The good things: the hotel is stunning. There is a gorgeous courtyard with a manicured lawn overhung with trees and flowers. It's perfect for breakfast. My room was also gorgeous- every detail was beautiful. Even the doors were carved with a floral design. The staff is very helpful.  The less good things: I got about 90 seconds of hot water for 2 out of 3 showers. There was neither a/c nor a fan.  Merely irritating things: the front door is locked, so every time you come back to the hotel, you have to knock and hope someone heard you. Also, it's a little ways from the central part of town, but it's a small town, so that's only about 10-15 minutes of walking.",
#   "Hotel Casa Noble was perfect for my quick stay in Antigua. My boyfriend and I had a junior suite on the second floor with a great view of the volcano when we stepped outside our door.The room was clean, had great natural light and a fireplace. King sized bed was comfortable and actually big enough for my 6'3'' boyfriend to fit in. WiFi signal strength in rooms was strong. Location was great. Within walking distance from the central park and the walk home late at night never felt un-safe. The staff was incredibly friendly and always willing to help with directions and/or advice. The breakfast in the courtyard/garden every morning was fantastic! Great choice for the price.",
#   'It’s a great location within walking distance.  Beautiful property, and the access of the sister property is wonderful.  The buffet at La Porta, the sister property is second to none.  I would recommend this place to my family and friends.  The only issue is, the morning and afternoon traffic from Antigua to GUA can be quite heavy, up to two hours.  Keep this in mind with flights, as I missed one of mine.  ',
#   "This was quite possibly the cutest boutique hotel I have ever stayed in, and I've stayed in A LOT. It's quaint, quiet and relaxing but you also have access to the larger resort across the street so can enjoy some additional amenities like restaurant, bar and pool (but Casa Encantada also has a pool!). The room was small but we never spend much time in the room when exploring a new city so that doesn't matter. It was well decorated and comfortable. The staff were all very friendly as well! The breakfast on the rooftop was also delicious and it was so nice to soak up the sun on the rooftop every morning. You can pretty much walk all of Antigua so the location is perfect and not on a super busy street. I wouldn't stay anywhere else in Antigua!",
#   "Fabulous boutique hotel with a staff that couldn't be more wonderful!  I would like to thank Melvin, Karen and many others whom I can't remember.  I highly recommend Casa Encantada to stay in the most beautiful colonial town in Latin America.",
#   'Great service and perfect location for us. We have stayed a couple of times and will definitely look to use again. It was very convenient for our needs. The central square is close enough but you are not right on top of it.',
#   'Casa Encantada and the sights, sounds and flavors of Antigua absolutely enchanted us.  We spent a week in February at the intimate 10-room B&B in the heart of the colonial Guatemalan city. The attractive and peaceful two-story white cement building has red roofs and exposed dark wooden beam accents. A courtyard garden surrounds a plunge pool with three comfortable cushioned sunbeds.  Our top floor studio – and only one other suite – opened on to a sunny terrace and included efficient Wi-Fi, a quiet mini-fridge upon request, TV, safe, robes, deluxe toiletries and a large walk-in rain shower. Cool nights and three windows made A/C unnecessary.   Complimentary coffee, tea, drinking water, ice and cookies were available downstairs in the living room 24/7.  We began several days with',
#   'My opinion is this Ht. is cheap w.\\ Excel. Value > 9.5/10 RM.: Economy DR as described w.\\ smaller size but enough + G. TV (Many Channels in Spain only) & Small Window without curtain _Can promote /Suggest: Add small table /desk under window & Hangers behind door & Add Mirror  Shard B.R.: @ 1st. fl. =1 complete set (Shower +Toilet +Sink) w.\\ hot water + Shampoo + without Elect. Socket or Hangers _@Gr. Fl. 1 small (Toilet +Sink) _ Some /Most Rms. W.\\ Private B.R. HT.: 7 Rms. /2 Floor _V.G. Big Terrace in 1st. fl. with City /Mountain V. _Another Sitting A. in Gr. Fl. Plus small common Kitchen but enough due Ht. size (Ref. +Microwave +Oven) incl. 24hr FREE water STF.: Map +Info. +Free bottle of water +Help +Secure Gate +No Eng. _But Collect +3% For Credit Pay not exist in Web So,',
#   'Ended up here after a long search through Antigua for an affordable hotel. For some reason prices were extremely high at other places because of the weekend.. We were welcomed by a friendly young woman who showed us the room. Had a private room with a nice bed on the first floor at the front of the building. The shower was actually one of the best we have had, good amount of water and warm (hot!). We also had breakfast which was Tipico Guatemala and really nice. So if you are looking for an adorable place with a nice spacious room, go for it! On the map it looks way out of the city centre but actually it is only a 5-10min walk.',
#   'Nos quedamos 3 noches en el hotel de Cortez y Larraz y la experiencia fue muy positiva. El personal es muy atento y amable. Las habitaciones muy limpias. Localización céntrica y precio muy asequible para la calidad que tienen. Muy recomendable',
#   'Somos 2 amigos de España que hemos venido a Guatemala todo el mes de febrero, y nos hemos hospedado aquí casi la mitad del mes de febrero y algunos días de marzo. Tiene una terraza muy acogedora donde puedes leer o cenar en un ambiente relajado. El personal vive anexo a la edificación del hotel, con lo cual siempre está a su disposición para cualquier contratiempo (hemos llegado al punto de pedir que nos revisaran el agua caliente y nos han ofrecido su propia ducha mientras solucionaban el problema). En resumen, totalmente recomendable para hospedarse en La Antigua. ',
#   'My wife and I have stayed here three times; Hector (the owner) and his wife and staff are wonderful  and very helpful; they speak enough English to suffice and Hector will pick you up at the airport for a reasonable fee (recommended); very clean and soooo convenient being just one block from the Plaza.  We would stay here again. Tom Coohill Albany, NY',
#   "No Tv, no fan, rooms with 2 beds,  small shower private bath room. No breakfast.  High speed Internet. Hot water. Spanish only. Large double wooden doors keep street noise out. Clean. Location, location.  Recommended for budget traveler's.  MeuterMedia",
#   'I have been traveling to Antigua Guatemala for many years now. Over the years I have stayed in many places, but Casa Mariajose is the best. when you travel to Guatemala do not assume that your hotel will have all the comforts of your hotel in the USA. Casa MariaJose has plenty of hot water supplied by a hot water tank, the staff is friendly and helpful, the rooms are clean, good wi-fi, the hotel is in a convenient location, the hotel is safe and secure. You can have your laundry done at the hotel and best of all the rates on the rooms is very fair. I recommend you stay here if you are a lone traveler, a group or family',
#   'Casa Maria Jose ("MaJo") is very clean, quaint, family owned and operated.  The rooms were very quiet and comfortable.  The price was reasonable (around $25 a night).  Each room has a private bathroom, which is clean and functional.  MaJo offers free WIFI (which is important since your SIM card probably won\'t work in GT).  It is located about two and a half blocks from the Arch on 5th Ave., which is a tourist focal point in Guatemala.  Casa MaJo is about six blocks in total away from the Central Square.  So it is within easy walking distance of most places in Antigua.    The only negative is that the hotel is pretty simple.  It does not offer breakfast or much in the way of amenities.  It does not offer tour packages.  It does offer free coffee and cookies.  Fortunately, there',
#   "This was my 1st time in Antigua Guatemala and it did not disappoint. I was here for a 2-week mission trip and the staff here made it feel like home. Every day they greet you with a warm smile and ask when you would like coffee the following day and offer to make breakfast for a charge. Their breakfast was delicious. You get eggs, plantains, mashed up black beans, bread, or pan dulce. Jose was very kind and would bring a bottle of water to your room every evening and ask you how your day went.   The view when you walk out of the hotel is spectacular where you can see the volcano. Its close to the Arch which is near many restaurants, shops, churches, and bars.   You do need to turn on the shower and wait a couple minutes before it gets hot but it wasn't a problem for me.   The",
#   'Spent about a week here and didn’t want to leave!! From the moment we checked in we knew it was going to be an amazing experience. Great pool, lovely city, and friendly locals and staff. I can not recommend this place enough and can’t wait to return. Definitely found our new go to spot when we need to unwind from life in NYC',
#   'Beautiful property and luxurious amenities. Room was clean and updated. Excellent bed and cosy in-room fireplace to take the chill off lovely garden, pool and terrace. Within walking distance to everything! ',
#   'We had a wonderful time everyone was very professional. The food was great. We were there with friends for a wedding. The only complaint would be the kitchen and Bar closed at 11pm on Friday. would stay there again. ',
#   'very nice stay, nice corner garden room, with confortable beds. bathroom a little small but confortable, need more space in the bassin may be  Delicious breakfast at the hotel as well as the bar ,i had some sándwiches to remember... very nice attention, i would really recommend your stay in Porta Antigua',
#   'A few blocks from the center but close to the public market and "chicken bus" station if you are travelling that way. I had a small budget room but it was comfortable, clean and had hot water. I didn\'t try the breakfast. The staff are friendly and most speak some English if that is a concern. You are given a key so you can come and go as you want without bothering the staff.',
#   'We have been visiting this wonderful hotel for the last three years. Family-run hotel that is friendly and helpful.  The hotel is very clean with an attentive staff that arranges your room around your schedule.  Breakfast is included and they offer a choice of a typical Guatemalan breakfast, pancakes with fruit or a healthy choice of yogurt with granola and fruit.  The location is quite convenient: just 1 block from La Merced Church, 2 blocks from the famous Antigua Arch, and 5 blocks from the central plaza. Cable TV includes hundreds of channels, access to WiFi and hot showers at all times.',
#   'We started in San Juan la Laguna made it almost to Mazatenengo before we hit the protest/ road closed until 6 pm. We rent a car and avoid driving in the dark especially when we are not familiar with where we are going. So all the way around above lake Atitlan hit Antigua wiped, We went straight to ST  Hilda (the owner) is running it and it is cleaner and nicer than even before (with Hecteo and Anabela) 242Q for a night. There is a place to park nearby 50Q for overnight so not the cheapest place but often worth it.',
#   'Great place to stay overall. The room was spacious and clean. The staff was also very friendly and helpful. It has a nice patio and balcony where you can relax. And if you walk a minute you are right in the hart of Antigua. I would 100% recommend this place.',
#   'The staff at Hotel Posada Santa Teresita is  friendly and helpful. The owner is lovable. The room was simple but nice. Location very good, but a bit away from Plaza Mayor. Good value for money. Generally, I  recommend this place.',
#   "Reasonable price, good comfortable budget hotel includes breakfast which was fine Friendly helpful staff. Not the most beautiful place with views and situation but atmospheric as buildings of their time. Would have stayed longer but they didn't have a room as booked up",
#   "We stayed at this hotel for 3 nights. Hotel is lovely, rooms are comfortable with modern bathrooms. It's slightly further away from the centre of town, so while this is ok during the day, it may make some people feel slightly unsafe walking there late at night, as the streets are not well lit. We had no problems though. Breakfast here was fantastic - freshly made to order and huge servings. The only thing we would say is that the service isn't fantastic. Since it is a small hotel, quite a lot of the time there is only one staff member available, and sometimes this person did not speak English. We had a few times where we had some questions and couldn't really get assistance from the hotel. But we still enjoyed our stay here, as this didn't bother us too much.",
#   'Some friends and I arrived for an overnight stay while we awaited our weeks long adventure in language school.  My room was very well kept and comfortable and I had no problem sleeping when that time arrived.  It is a smaller hotel - about 8-10 rooms - but it was modern in its amenities from TV to wifi and private bath with hot water.  There was an oscillating unit to move the air and keep it comfortable. There was also a staircase that led to the rooftop and a spectacular view of Volcano Agua and the rooftops of this colonial city.  The hotel also serves a choice of typical Guatemalan breakfasts in a cozy dining room.  We each chose a huge bowl of freshly cut fruits - melon, pineapple, watermelon, papaya, bananas - that was more than any of us could finish. And piping hot fresh',
#   'This hotel was lovely, it was reasonably priced, clean and very central. I cannot say enough about the kind, kind family that run this hotel. They are good people eager to help create a lovely welcoming environment.',
#   'We stayed at San Rafael for 3 night in March 2020.  Our room  was great and the service was amazing!!!  They suggested wonderful restaurants ans a great walking tour to start off our trip... The hotel grounds are private and beautiful perfectly located within Antigua!  The stay surpassed any expectations we had and highly recommend to anybody visiting Antigua!!!',
#   'Walking off the street into the first courtyard is like walking into a different world. The lush, beautiful plantings and flowers accented by the fountain were just amazing.   My room was spectacular, beautifully decorated, comfortable, and private. I had fresh flowers and a bottle of wine waiting in the room when I got in.   The staff was wonderful, so helpful with all my needs.  Most spoke English which was greatly appreciated since my Spanish is bad.  They made great restaurant recommendations, as well as shopping suggestions.    The breakfast menu had nice variety of choices, I only wish I stayed longer to be able to try everything. ',
#   'San Rafael is very conveniently located in the heart of Antigua.  My wife and I had the pleasure of staying there last week for 7 days.  Attentive, friendly staff, beautiful property, immaculately kept.  It will be our go-to hotel in Antigua.  Look forward to our return.',
#   'Beautiful colonial-style hotel. We loved staying there and cannot wait to go back! Having coffee in the courtyard surrounded by beautiful plants and the sound of water falling from a nearby water feature was so relaxing! The rooms are wonderful. The receptionist Thelma and everyone that worked there was so helpful.',
#   'The hotel is beautiful,it reflects an old Antiguas house, but is modern, clean, romántica and the attetion of the personal is amazing. The location is spectacular, near th arc of Santa Catalina and 2 blocks from the Cathedsrl. 100% recommended',
#   "The room has a view on the main street of Antigua. The location is very central and there is a very small balcony that allowed us to see the busy street from the second floor. The rooms have Wi-fi, TV and a safe. There's no problem with hot water in the shower.  The breakfast is served every morning on a roof terrasse that is beautifully decorated and where you can also hang out throughout the day to read or browse internet. The woman serving breakfast is super nice and the breakfast are delicious: there is a choice of main meal and there is a food display of: coffee or tea, fresh water, bread, cereals, fresh fruits and cheese. Fresh orange juice was also part of the breakfast.  Only negatives: I think you pay more just because the location is on the main street. Also there is",
#   'Nice hotel in central location.  As a word of warning despite what is advertised on their website, trip advisor and booking.com this venue does NOT have a 24 hour reception.  We found out the hard way when a member of our group was expecting a delayed bag to be delivered.  To their credit the hotel management team did go the extra mile to help try and recover the bag the next day.',
#   'Nice place to rest in the city center of Antigua Guatemala. 100 m away from the central park and the cathedral. Homemade breakfast. Kind people. Restaurant in the lobby. Nice terrasse to rest and read.',
#   'We stayed at this hotel on three separate nights, interspersed between trips around Guatemala (arrival to Antigua, Lake Atitlan, Antigua, Flores, Semuc Champey, Antigua...). When we arrived back here for the third stay, we genuinely felt as if we were coming "home" to a nice, clean, high quality place where we could get a great hot shower and a good night\'s sleep.   The breakfast is great, and they also provided us a breakfast "to go" on two mornings as we had very early starts. This was a simple sandwich and juice, but it was much appreciated. We were also able to leave our bags here and return later in the trip so we didn\'t have to carry all our stuff with us when we left for a few days at a time. It\'s all these little things that really helped us fall in love with Casa del',
#   'We stayed for 3 nights. Room was clean and we had enough space. Shower and toilet also in the room. Bed was oké. The room was situated at the front of the hotel at a busy street, so there was noise till late in the evening.  Upside was Pati, the manager. She helped us out with all the answers to our questions. ',
#   'We stayed 4 nights at the end of April the hotel is charming and the rooms were beautiful and clean with the location close to everything , the courtyard was beautiful and the pool was appreciated after days out touring and enjoying Antigua , they arranged tours to Pacaya and Lake Atitlan for us which were excellent . The staff were great with Mildred being fantastic in looking after us , we really enjoyed our stay',
#   'This is a great  hotel. the location is amazing, only half a block from the City Center and 3 blocks from the famous Arco de Santa Catalina. From the erstaurant and pool you have a spectacular view of the Volcano de Agua. The services ia fantastic, ask from Rosy, Milderd or Luis at the front desk. The are very helpful and friendly. They also are pet friendly, the always put food and water outside for street dogs.  The rooms are really beautfiul you will really enjoy it.',
#   "My friends and I were only able to spend one night in Antigua. We stayed at the Casa del Parque hotel and we were not disappointed. It's absolutely charming and the staff is delightful. Our room was located on the second floor with gorgeous view of Fuego. We could even see it erupting! ",
#   'This hotel is beautiful. It is clean, the staff is wonderful and attentive, the pool is great, and the location is wonderful. You can walk to the park in seconds and there are a ton of restaurants within a few minutes walk. Plus there is an amazing Gelato place next door.   I stayed in room 9 on the 2nd floor, away from the Lava Club. It is way too loud. I had to wear earplugs and download a white noise app on my phone. I do have insomnia so this is part of the problem. The other issue is there seems to be very thin walls between my room and the room next to mine, so I became intimately acquainted with the people in the room next to mine, and could hear them using the bathroom at all hours of the night. This is really my only complaint. I am on the second floor facing the',
#   'We came here for our friends’ wedding. We have enjoyed every moment of our stay here. This hotel is awesome, with the museum & everything. I highly recommend it to anyone who cares to come, relax, & visit Antigua & the surrounding area. It’s so beautiful.',
#   'My husband and I arrived at these hotel and were presently surprised at how upscale it was! Everyone was nice and helpful from the wait staff to the restaurant staff. If you stay in Antigua you have to stay at this five star hotel. A added bonus is the Spa, Museums, and the chocolate factory!',
#   'An unparalleled experience in Antigua. Totally recommended. For a short stay, the hotel offers so many amenities and internal museums that it is not necessary to leave it to spend an unforgettable weekend.',
#   'The room was massive with a wood burning fireplace. The staff treat you like royalty and the amenities are world class. A tranquil spa, museums within the hotel and a beautiful pool. Truly an awesome stay.',
#   'Probably not just one of Guatemalas most beautiful hotels, but from all Central America. Unique mixtrure of colonial and modern architecture. A lot of stunning gardens and colonial ruins inside the hotel property. Beautiful rooms, good food, great service, incredible spa area... an unforgettable experience in the most beautiful city in Central America.',
#   'I went with my family (wife and kids) and we liked a lot the service, the staff were nice and the rooms were clean and comfty. The best is the location very close to supermarkets, stores, and the main attractions of the city. They also offered us a guided tour to Pacaya and they conect us with these guys.   I would definitively come back in a few months to Antigua and will stay at St. Agustin.',
#   "rules worse than a family, reception does not have information to do of tourism, room smells damp; clothes smelly with moisture; kitchen; You can not use after 8 p.m. small walls you can listen in front of your room, include very simple and unpleasant breakfast in another hotel and shower not harm, the bed wasn't really great, lot of noise in the morning",
#   'My best friend and I went on a trip to hike Acatenango volcano in Antigua Guatemala as a New Year trend setter. We shopped around for accommodation in the beautiful old capital but could not resist the appeal once we found San Agustin! The friendly, informative, accommodating service we received from Alex at the reception was too captivating to get past. We stayed there for 3 nights and we have never regretted it. In fact it turned out to be one of the best choices we made in the trip. Alex also became our Antigua guide making recommendations for places to visit etc :) . Breakfast was included in the price which was quite reasonable and a great breakfast too! The room was well maintained and clean. Wi-Fi was good and the overall experience great!',
# ...
#   "We arrived and our private room had little cockroaches all over the bed, our bedroom light didn't work and the music was vibrating through the walls. We love to party but like to come back to a clean room and be able to go to sleep when we want. I will say that the lady at the front desk was incredibly helpful and apologetic when we asked her to help us find a new hotel at 10.30pm at night (after we had decided enough was enough!) she called around and got us somewhere down the road. Don't know how this place is so high on trip advisor.",
#   'This is not the place for you unless you are a 20-something student interested in partying, getting wasted and meet just other students. You will not get a good night sleep, because so many people come in and out all the time, they scream loudly in the hall, they will be drunk at 4 am and try to open doors. The hostel is falling apart - let me not mention the hygiene of the bathroom, the shower which you will be sharing with many people, the non-existent quality of the mattress (unless you like feeling springs on your back while you sleep), the tiny cramped room, the synthetic linens etc. Gosh I am so glad we are leaving today.',
#   'The hostel is beautiful, so much so that you might even forget yourself and believe you are in a boutique hotel. The staff is incredibly sweet and helpful.  However, our initial love for the place was soon replaced by incredible annoyance and frustration. It’s Sunday at 8am and they have been hammering away since 7:30am. The noise is so intense we were woken up by the hammering and sound of workers. ITS SUNDAY!?   And on top of that the rooms have a sky light (which does not have a black out) which also means you are woken up by the sunrise. Maybe the early morning would not have been a problem if not for the party they had until late the previous night.  Although we initially loved the place, we are now quite disappointed with the outcome. Would not recommend for anyone seeking',
#   'The only reason for the #4 rating was the rooftop patio view, where my fellow travellers would congregate with a bottle of wine at the end of the day to watch the sunset over the volcano. The rooms were nice and large and clean as was the bathroom. The breakfast "buffet" was not too bad. My only beef was to do with slow response to the room\'s only light bulb which expired and it took 4 hours before a person came with a ladder to install a new bulb. Other than that, close to everything. Breakfast only. Wifi at the office.',
#   "Stayed here during the semana santa. The location is fantastic. The rooms are basic, no tv, simple furniture and some rooms have a few maintenance issues. The rooms are rather small but clean. Free wifi is available throughout and the staff members are great. Their attitude and manner clearly compensate for the shortcomings of the rooms. Breakfast is not available in the hotel but the next door cafe, Fernando's (which I understood is owned by the hotel) offers great breakfasts and coffee. I was a bit put off by the rather excessive price for this hotel, but that may have to do with the fact that I stayed here on one of the busiest days of the year. They charged $ 84 a night which is about double of what a hotel of this class should charge. This hotel is a good option for basic",
#   "I spent one night in Tropicana, actually I was planing a hike trek to volcano acateningo with Tropicana. The night, which I really need to sleep was trerrible, although I spoke with the guide in reception many times,the loud music continued untıl 11 pm and couldn't have a good sleep.If you are not a party perdon, don't stay in this hotel The day after we were taken from Tropicana for hiking Antigua.It was also disappointment, because our local guide never looked behind and was very fast, 3 of us ın the group were lost once. Even I warned the guide, he didn't change his behavior. And in the morning we have to wake up early but our guide was sleeping!! In chance I woke up at the time, and tried to wake up him!!",
#   "Bigfoot has plenty to offer tourists and travelers who enjoy the vices of the night life.   The location is pretty great, only a couple of blocks from Central Park. Several fun options for restaurants, bars, and night clubs all within blocks of the front door.  Or if you even want to stay in, there is dining, drinking, dancing and mainstream music lasting through the night (until around 11:00 - 11:30pm).  ALSO there is a quaint Jacuzzi in the back (for guests only) which closes at 10:00pm (I wish this was open later).  While the private rooms look dank as hell, the shared dorms are (in my opinion) lacking. Yes, you're provided lockers, but the bunks are absent of a personal light or electric outlet. I was assigned to dorm #6, bed #21, and the entire room had but 1 electrical",
#   'This hotel is used a lot by G-adventures groups,  so if you\'re looking for a quiet place to sleep,  this is not the place for you. You might be lucky and avoid a group, but chances are you won\'t.  I was with a G group myself, so I was quite pleased with the place.   + Wifi (works in the "lobby" and some of the rooms) Clean rooms Hot water in the shower (not when the whole hotel decides to shower at the same time)  - Beds are hard as concrete Not very helpful staff No breakfast A few ants in the bathroom',
#   'I stayed here as part of my tour so as everything was organised for us I had no contact with the staff at the hotel. AIt is situated a short walk from the Parque Central this hotel was basic but comfortable.',
#   'We decided to sleep at a this hotel to aviod the ruthless drunk loud people that crowd the hostels in Antigua. However, they managed to find their into Santa Clara, the rooms next to us. The noice started at after 1 am and ended after 3.30 am, after we repeatetly asked the noisy guests politely to be quiet and respect that other were trying to sleep. We told the guard about the troubles, twice. The first time he talked to them, it did not work. The second time our neighbours kept talking at 3.30 am, the guard did not even come up.   The rooms were nice, and the building itself too, but our loud neighbours ruined the stay.',
#   'Rooms dont lock very good. No travel desk. Breakfast is just rice and beans. No coffee or thea. No hot water and no english speaking staff like it tells al of the above on the website.  Also cant pay by card. Room is rather grim with no lock and no windows.  All together very muxh overpriced ',
#   "I'm not sure how this hotel has been described as charming? Maybe the older gentleman who works there can be but I would say that's where it stops. Granted he was nice to us when we wanted to cancel the second night we originally booked! The positive of this hotel is that it is quiet. After reading countless reviews of other places in Antigua where they all seem to struggle with noise, this hotel was at least quiet. BUT... our room was tiny, dingy and dark with a very suspicious shower that electrocuted my husband! The place had no atmosphere what so ever and there wasn't any hot water. It's the kind of place that you leave feeling dirty! We stayed the one night and left in the morning so I can't comment on the breakfast as we pretty much wanted to leave as quickly as possible.",
#   'I recently stayed at the Casa rustica on route to San Pedro. The hotel was strangely arranged with a pool table awkwardly in the middle of your way when checking in. The front desk staff were not helpful with suggestions for food. The other guests had to step in and offer suggestions. The american owner (presumably) was right there behind the desk but remained silent when I was trying to communicate with the staff who had little English. He could have easily assisted in our stilted communication. My room was $42 with a shared bathroom that was not close to the room. My room was cramped with a double bed and a single bed but only had room for either beds on its own. The ceiling was low and the combination of all the beds made the room feel claustrophobic. When I got into the bed',
#   "Anywhere you stay, your expectations will heavily influence your impression and review of a place. If you expect a budget hotel where you are located in the centre of town where there are multiple bars nearby than I think most people would be ok enough here.   We booked knowing that there was a bar beside the hotel and expecting we'd hear some noise at night. But we chose Rustica as it seemed optimally located and the price range we were aiming for.  Location - just a block from the central square/park its right in the centre of things. That said, we realized after arriving that Antigua is very small, the blocks tiny and that places we'd discounted for being too far away were only an extra minute or two's walk.  Rooms - small, basic, a little dark. But with nice touches like a",
#   'We stayed there for a wedding and really only wanted a place to sleep. Unfortunately our room was very close to the street so it was a bit noisy. Clean and centric. Would stay there again if it was the only option but would look around first.',
#   "Stayed here over the Halloween weekend in a private double.. Which was ok quality but not the best value for money compared to similar rooms in other hostels in the area (which were fully booked all weekend). Expected it to be a bit of a party hostel but didn't expect the terrace bar to be quite so noisy all though the day - the room was right underneath the bar and kitchen so we could hear the music and boxes and bottles being dragged around from 8am til midnight, not great if you needed a power nap (which we did after a nasty night bus down) or wanted to sleep in at all. Lots of locals or people from other hostels seemed to visit the bar and they tended to hog the upstairs bathroom (one of only three for the whole hostel) when they were around. The showers were a little tricky",
#   "Don't be mistaken, this is a 2 star hotel at most. Definitely not what you would expect from the price they charge. There is not much to say, the only two things above the average in this hotel are the location and the price, as for the rest (rooms, the bed and bathroom) is like I said something you would expect from a B&B or even a hostel. Even more, the rooms are located around the hotel restaurant so its very noise, definitely not a good place to rest.",
#   'Stayed 4 nights here in November 2018. Comfortable room and beds. Good hot shower. Gardens look good but no comfortable seating in it and plenty of insects to bite you. Very average breakfasts...we gave up after two days and went out for breakfast. This place is well away (4 blocks and half a km) from the centre of town and on a quiet street.  You will not want to walk back late at night. The fact that the place has a locked gate and an armed guard tells you all you need to know about security concerns.',
#   'I work in the tourism industry, which is why every time I stay at a hotel and I have a bad experience, I try to speak to the people who manage the properties in order for them to know what is wrong and show them where they can improve.  Unfortunately the case with D`Leyenda Hotel was not only the worst experience I have ever had: the parking lot is 6 blocks away from the hotel, there is a club beside the hotel that keeps you up until 1:30 AM, the room was smaller than the pictures show and to finish things up, I was woken up at 5:30 AM by the sound of people working in the restaurant preparing breakfast. Not only did all this happen in just one stay, the next day when I tried to explain the case to the front desk agent, she did not even care and the “general manager” never',
#   'This is a small establishment that is kid friendly. It is nice they have a playground for the kids but it is loud. There are small windows to open to get some air but then you hear all of the noise from the courtyard. There is no air conditioning in the rooms and the rooms get hot. The beds are comfortable and the rooms are big. Small bathroom with no room to put anything anywhere. The worst part is the time it takes to get breakfast. It is included but it takes almost an hour to get your breakfast. Plus if you are there many days it is only the same thing every day, which gets old if you are there a week. The hotel itself is pretty nice but there are so many places to stay in Antigua that provide a better value. ',
#   'When we booked, we booked one double and one triple room (with 3 twins).  We were switched from the triple to a tiny room with 2 double beds when we arrived and the room was located in the very back next to the laundry which was quite noisy.  This got us off to a bad start.  Also the room had no available outlets for phone charging,etc.  Under different circumstances, we might have liked staying here.  They did serve a very nice breakfast but coffee is not available for early risers.  It is very well situated in the town.',
#   'About 5 minutes walk to the main square where there are many shops, restaurants and bars. Pleasant, well restored traditional hotel. Good rooms with queen sized beds. Old style TV. Roof light with no blind so woken quite early by light which was not a problem. No A/C but not needed. No tea/coffee. Good free Wi-Fi in room. Good shower and shower room. Very pleasant courtyard. Supermarket next door.',
#   'The rooms are ok, they are clean, and the building is nice.  Unfortunately the atmosphere was a bit cold, not much light in the whole building, no staff around when I arrived. There might be better places in the same price range.',
#   "It's not take you so long to reach the downtown. The advantage of this hotel was there was a small bakery nearby (just 2 mins walk). It's not expensive. The taste was good. There was a convenient next to the hotel as well. It's pretty a good location for me if there were some shops nearby. I was so sick when I traveled in Antigua. All of my tour group went to travel during the day, but I had to take a rest at the hotel, so, it's like I went to the pastry shop a lot because I didn't have enough power to walk too faraway from the hotel. I can say that 'that bread saved my life.' haha....Antigua is a old town with a beautiful landscape of volcano. You will like this city.",
#   'We stayed here as part of our G Adventures Tour. The rooms were small & basic with  the hotel just  a short walk from the main square. Not a great hotel but there is a shop just outside to buy drinks and snacks and a nice bakery next door which also does a tasty breakfast. We had a nice view of the volcano from our room which was a bomus but we saw more inviting hotels around Antigua.',
#   "This place is the type of place you get what you pay for.. Not much to it, quite simple.  It does have a daunting entrance, with the timber doors opening up to a nicer venue.  The hotel is different.  The rooms are quite dark and eery, the bathroom is very basic, but larger than i thought it would be.  No in room safe or air conditioner.  but that isn't much of a problem, as it is quite safe behind the high brick walls and solid timber gates, and the exposed concrete/brick rendered walls in the room act as a good insulator to keep the heat out.    Not the most inviting place, if you blink you will miss it.  Right next door there is a convenience store for you to purchase your snacks drinks or smokes.  next door on the other side, you will find a nice bakery which makes a nice",
#   'Everything was fine until the room next to me (second floor) was occupied. Not only could I hear everything, but when they farted I could smell it.... Dorm living at private room prices.  Otherwise clean and helpful staff.',
#   ...]}

# %%
positive_reviews = review_classes['POS']
negative_reviews = review_classes['NEG']

# %%
def sentences_to_words(sentences: List[str]) -> List[List[str]]:
    words = []
    for sentence in sentences:
        # https://radimrehurek.com/gensim/utils.html#gensim.utils.simple_preprocess
        yield(simple_preprocess(str(sentence), deacc=True))  # deacc=True elimina la puntuación

# %%
def remove_stopwords(documents: List[List[str]]) -> List[List[str]]:
    return [[word for word in simple_preprocess(str(doc)) if word not in stopwords.words('english')]
            for doc in documents]

# %%
def learn_bigrams(documents: List[List[str]]) -> List[List[str]]:
    # We learn bigrams
    #  https://radimrehurek.com/gensim/models/phrases.html#gensim.models.phrases.Phrases
    bigram = Phrases(documents, min_count=5, threshold=10)

    # we reduce the bigram model to its minimal functionality
    bigram_mod = Phraser(bigram)

    # we apply the bigram model to our documents
    return [bigram_mod[doc] for doc in documents]

# %%
def lemmatization(nlp: English, texts: List[List[str]], allowed_postags: List = None) -> List[List[str]]:
    if allowed_postags is None:
        allowed_postags = ['NOUN', 'ADJ', 'VERB', 'ADV']

    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
nlp = spacy.load('en_core_web_lg', disable=['parser', 'ner'])

# %%
def tokenize(documents: List[str]) -> List[List[str]]:

    document_words = list(sentences_to_words(documents))
    document_words = remove_stopwords(document_words)
    document_words = learn_bigrams(document_words)
    document_words = lemmatization(nlp, document_words)

    return document_words

# %%
positive_words = tokenize(positive_reviews)

# %%
negative_words = tokenize(negative_reviews)

# %%
with open(r"C:/Users/chiruco/Desktop/python/ProyPython/SentimentalAnalysis/SentimentalAnalysis/data/interim/positive_words.pkl", "wb") as output_file:
    pickle.dump(positive_words, output_file)

with open(r"C:/Users/chiruco/Desktop/python/ProyPython/SentimentalAnalysis/SentimentalAnalysis/data/interim/negative_words.pkl", "wb") as output_file:
    pickle.dump(negative_words, output_file)

# %%
negative_words
# Out:
# [['town',
#   'especially',
#   'be',
#   'go',
#   'antiguena',
#   'good',
#   'sized',
#   'private',
#   'twin',
#   'room',
#   'shared_bathroom',
#   'great',
#   'price',
#   'nice',
#   'ish',
#   'garden',
#   'swing',
#   'basic',
#   'bathroom',
#   'tatty',
#   'hot',
#   'shower',
#   'always',
#   'keep',
#   'water',
#   'flow',
#   'slow',
#   'super',
#   'basic',
#   'pretty',
#   'dirty',
#   'kitchenette',
#   'load',
#   'cat',
#   'dog',
#   'cheap',
#   'basic',
#   's'],
#  ['go',
#   'hotel',
#   'directly',
#   'book',
#   'room',
#   'receptionist',
#   'first',
#   'really',
#   'high',
#   'price',
#   'lower',
#   'ask',
#   'much',
#   'cost',
#   'qetale',
#   'comission',
#   'rate',
#   'dollar',
#   'know',
#   'randomly',
#   'gove',
#   'non',
#   'exist',
#   'rate',
#   'lower',
#   'real',
#   'rate',
#   'agree',
#   'price',
#   'include',
#   'breakfast',
#   'follow',
#   'morning',
#   'get',
#   'breakfast',
#   'receive',
#   'plain',
#   'piece',
#   'toast',
#   'fruit',
#   'theother',
#   'table',
#   'receive',
#   'also',
#   'egg',
#   'ask',
#   'also',
#   'egg',
#   'reply',
#   'come',
#   'breakfast',
#   'pay',
#   'good',
#   'experience',
#   'hotel',
#   'place',
#   'stay'],
#  ['go',
#   'break',
#   'good',
#   'bad',
#   'good_location',
#   'free_breakfast',
#   'warm',
#   'helpful',
#   'staff',
#   'hour',
#   'massage',
#   'bad',
#   'small',
#   'room',
#   'great',
#   'air_circulation',
#   'awful',
#   'quality',
#   'bed',
#   'noisy',
#   'dog',
#   'let',
#   'decide',
#   'important',
#   'awful',
#   'bed',
#   'kill',
#   'massage',
#   'make',
#   'feel',
#   'well',
#   'choice',
#   'sure',
#   'come_back',
#   'back',
#   'handle',
#   'way',
#   'night',
#   'advertise',
#   'totally',
#   'wrong',
#   'end',
#   'night',
#   'triple',
#   'room',
#   'really',
#   'worth',
#   'many',
#   'choice'],
#  ['night',
#   'delay',
#   'bus',
#   'journey',
#   'original',
#   'accommodation',
#   'give',
#   'away',
#   'place',
#   'could',
#   'find',
#   'could',
#   'accommodate',
#   'grateful',
#   'price',
#   'wifi',
#   'seem',
#   'decent',
#   'value',
#   'however',
#   'room',
#   'incredibly',
#   'basic',
#   'unclean',
#   'mosquito',
#   'everywhere',
#   'insect',
#   'floor',
#   'bathroom',
#   'key',
#   'door',
#   'apparently',
#   'however',
#   'lock',
#   'inside',
#   'feel',
#   'secure',
#   'place',
#   'stay',
#   'night_guard',
#   'big',
#   'lock',
#   'night',
#   'staff',
#   'limit',
#   'test',
#   'see',
#   'much',
#   'else',
#   'bathroom',
#   'bedroom',
#   'morning',
#   'come'],
#  [],
#  ['dirty',
#   'offer',
#   'towel',
#   'sheet',
#   'nasty',
#   'bathroom',
#   'gross',
#   'owner',
#   'take',
#   'dollar',
#   'give',
#   'receipt',
#   'terrible'],
#  ['use',
#   'tourist',
#   'shuttle',
#   'get',
#   'back_forth',
#   'country',
#   'pretty',
#   'often',
#   'book',
#   'shuttle',
#   'shuttle',
#   'woman',
#   'sit',
#   'phone',
#   'look',
#   'time',
#   'tell',
#   'come',
#   'minute',
#   'standard',
#   'sometimes',
#   'bus',
#   'pick',
#   'early',
#   'sometimes',
#   'pick',
#   'minute',
#   'late',
#   'today',
#   'bus',
#   'minute',
#   'late',
#   'still',
#   'wait',
#   'front',
#   'woman',
#   'say',
#   'fault',
#   'true',
#   'charge',
#   'inflated',
#   'price',
#   'later',
#   'shuttle',
#   'say',
#   'less',
#   'people',
#   'shuttle',
#   'price',
#   'expensive',
#   'finally',
#   'call',
#   'shuttle',
#   'company',
#   'say',
#   'pick',
#   'people'],
#  ['stay',
#   'home',
#   'last',
#   'weekend',
#   'want',
#   'room',
#   'nice',
#   'hotel',
#   'already',
#   'want',
#   'see',
#   'hotel',
#   'maybe',
#   'even',
#   'look',
#   'room',
#   'meeting',
#   'friend',
#   'take',
#   'look',
#   'arrive',
#   'early',
#   'clerk',
#   'personal',
#   'call',
#   'refuse',
#   'acknowledge',
#   'even',
#   'look',
#   'minute',
#   'early',
#   'take',
#   'look',
#   'lobby',
#   'pool',
#   'use',
#   'man',
#   'room',
#   'go',
#   'wild',
#   'start',
#   'scream',
#   'man',
#   'room',
#   'guest',
#   'scream',
#   'embarrassing',
#   'basically',
#   'kick',
#   'hotel',
#   'group'],
#  ['book',
#   'hotel',
#   'pool',
#   'parking',
#   'good',
#   'review',
#   'request',
#   'upstairs',
#   'room',
#   'balcony',
#   'get',
#   'room',
#   'clean',
#   'however',
#   'way',
#   'overpriced',
#   'get',
#   'tiny',
#   'quaint',
#   'rather',
#   'charming',
#   'room',
#   'big',
#   'drawback',
#   'noise',
#   'venue',
#   'bar',
#   'loud_music',
#   'reverberate',
#   'wall',
#   'way',
#   'go',
#   'able',
#   'sleep',
#   'credit',
#   'management',
#   'ring',
#   'bar',
#   'ask',
#   'turn',
#   'still',
#   'terribly',
#   'loud',
#   'manager',
#   'come',
#   'offer',
#   'room',
#   'hotel',
#   'happy'],
#  ['arrive',
#   'hotel',
#   'around',
#   'already',
#   'read',
#   'previous',
#   'review',
#   'want',
#   'charge',
#   'early',
#   'check',
#   'expect',
#   'bad',
#   'first',
#   'tell',
#   'room',
#   'available',
#   'wait',
#   'couple',
#   'hour',
#   'minute',
#   'wait',
#   'receptionist',
#   'call',
#   'say',
#   'room',
#   'available',
#   'charging',
#   'hour',
#   'early',
#   'check',
#   'standard',
#   'checking',
#   'time',
#   'pm',
#   'ask',
#   'additional',
#   'order',
#   'check',
#   'disappoint',
#   'upset',
#   'treated',
#   'way',
#   'specially',
#   'explain',
#   'already',
#   'pay',
#   'almost',
#   'red',
#   'eye',
#   'fly',
#   'want',
#   'rest',
#   'somehow',
#   'negotiate',
#   'still',
#   'rip',
#   'disgusting',
#   'decided_stay',
#   'additional',
#   'night'],
#  ['stay',
#   'total',
#   'nearly',
#   'week',
#   'visit',
#   'visit',
#   'already',
#   'reserve',
#   'family',
#   'friend',
#   'stranger',
#   'become',
#   'friend',
#   'slap',
#   'dash',
#   'haphazard',
#   'time',
#   'much',
#   'wifi',
#   'wonky',
#   'back',
#   'recommend',
#   'friend',
#   'oasis',
#   'expectation',
#   'courtyard',
#   'walk',
#   'way',
#   'hang',
#   'dense',
#   'flower',
#   'vine',
#   'spring',
#   'summer',
#   'add',
#   'flowering',
#   'shrub',
#   'tree',
#   'perfume',
#   'small',
#   'aspire',
#   'main',
#   'courtyard',
#   'add',
#   'bouquet',
#   'soundtrack',
#   'splash',
#   'water',
#   'perfect',
#   'place',
#   'sip',
#   'beer',
#   'read',
#   'book',
#   'fall'],
#  ['hotel',
#   'medium',
#   'size',
#   'make',
#   'big',
#   'effort',
#   'give',
#   'feel',
#   'colonial',
#   'town',
#   'feel',
#   'authentic',
#   'walkable',
#   'distance',
#   'central_park',
#   'block',
#   'food',
#   'good',
#   'coffee',
#   'however',
#   'people',
#   'bite',
#   'cold',
#   'make',
#   'eye',
#   'contact',
#   'bathroom',
#   'design',
#   'smart',
#   'step',
#   'open',
#   'door',
#   'light',
#   'switch',
#   'step',
#   'easily',
#   'trip',
#   'dark',
#   'shower',
#   'partial',
#   'wall',
#   'water',
#   'get',
#   'floor',
#   'make',
#   'slippery',
#   'pool',
#   'pretty',
#   'warmish',
#   'water',
#   'area',
#   'well',
#   'take',
#   'care'],
#  ['room',
#   'front',
#   'entrance',
#   'squeaky',
#   'gate',
#   'drop',
#   'oil',
#   'would',
#   'sort',
#   'problem',
#   'second',
#   'come',
#   'go',
#   'also',
#   'people',
#   'tend',
#   'stop',
#   'front',
#   'room',
#   'talk',
#   'could',
#   'look',
#   'window',
#   'closed',
#   'shutter',
#   'however',
#   'room',
#   'dark',
#   'maybe',
#   'room',
#   'upstairs',
#   'well',
#   'old',
#   'look',
#   'worn',
#   'fit',
#   'double',
#   'mattress',
#   'also',
#   'pillow',
#   'pretty',
#   'horrendous',
#   'towel',
#   'bite',
#   'threadbare',
#   'plus_side',
#   'shower',
#   'good',
#   'room',
#   'clean',
#   'could',
#   'decent',
#   'place',
#   'need',
#   'look',
#   'certainly',
#   'overpriced'],
#  ['place',
#   'dump',
#   'day',
#   'evening',
#   'day',
#   'shower',
#   'disgusting',
#   'waste',
#   'money',
#   'less',
#   'money',
#   'stay',
#   'hotstel'],
#  ['hotel',
#   'terrible',
#   'measureable',
#   'way',
#   'entire',
#   'stay',
#   'people',
#   'hotel',
#   'order',
#   'door',
#   'lock',
#   'properly',
#   'take',
#   'nearly',
#   'go',
#   'shower',
#   'extremely',
#   'cold',
#   'lock',
#   'big',
#   'issue',
#   'travel',
#   'girl',
#   'sit',
#   'shower',
#   'overall',
#   'stay',
#   'hotel',
#   'ruin',
#   'visit',
#   'beautiful',
#   'town'],
#  ['friendly',
#   'staff',
#   'room',
#   'amenity',
#   'close',
#   'town',
#   'centre',
#   'unlucky',
#   'apartment',
#   'own',
#   'really',
#   'like',
#   'sound',
#   'voice',
#   'like',
#   'drink',
#   'lot',
#   'make',
#   'stay',
#   'unpleasant'],
#  ['fairly',
#   'affordable',
#   'location',
#   'good',
#   'fairly',
#   'busy',
#   'loud',
#   'street',
#   'basic',
#   'amenity',
#   'work',
#   'clean',
#   'safe',
#   'place',
#   'nice',
#   'little',
#   'courtyard',
#   'hairdryer',
#   'overall',
#   'decent',
#   'place',
#   'picky'],
#  ['former',
#   'hotel',
#   'other',
#   'say',
#   'review',
#   'room',
#   'super',
#   'clean',
#   'bathroom',
#   'nice',
#   'flat',
#   'screen',
#   'tv',
#   'room',
#   'truly',
#   'cute',
#   'little',
#   'hotel',
#   'exceptional',
#   'nice',
#   'kind',
#   'super',
#   'friendly',
#   'owner',
#   'son',
#   's',
#   'make',
#   'review',
#   'little',
#   'difficult',
#   'want',
#   'love',
#   'hotel',
#   'support',
#   'hotel',
#   'owner',
#   'thing',
#   'likely',
#   'struggle',
#   'stay',
#   'kinda',
#   'noisey',
#   'parking',
#   'inside',
#   'literally',
#   'bed',
#   'asleep',
#   'pm',
#   'awaken',
#   'sound',
#   'car',
#   'backing',
#   'downstairs',
#   'noise',
#   'loud',
#   'enough',
#   'sound',
#   'sleep',
#   'garage'],
#  ['great',
#   'set',
#   'relax',
#   'lot',
#   'really',
#   'positive',
#   'stuff',
#   'resort',
#   'gym',
#   'good',
#   'pool',
#   'area',
#   'great',
#   'kid',
#   'playground',
#   'room',
#   'recently',
#   'renovate',
#   'smart',
#   'dinner',
#   'restaurant',
#   'good',
#   'staff',
#   'also',
#   'lovely',
#   'friendly_helpful',
#   'relaxed',
#   'vibe',
#   'negative',
#   'stuff',
#   'mainly',
#   'hinge',
#   'reception',
#   'experience',
#   'honest',
#   'arrive',
#   'pm',
#   'guy',
#   'reception',
#   'large',
#   'wedding',
#   'party',
#   'take',
#   'place',
#   'probably',
#   'bit',
#   'stressed',
#   'however',
#   'welcome',
#   'quite',
#   'dismissive',
#   'want',
#   'sign',
#   'various',
#   'paperwork',
#   'key',
#   'send',
#   'way',
#   'travel',
#   'hour',
#   'say'],
#  ['seem',
#   'new',
#   'good',
#   'working',
#   'order',
#   'impecable',
#   'breakfast',
#   'good',
#   'far',
#   'negative',
#   'parking',
#   'nightmare',
#   'parking',
#   'send',
#   'sketchy',
#   'place',
#   'parking',
#   'attendant',
#   'seem',
#   'confused',
#   'hotel',
#   'come',
#   'car',
#   'would',
#   'block',
#   'exit',
#   'end',
#   'work',
#   'well',
#   'also',
#   'bathroom',
#   'small',
#   'place',
#   'put',
#   'toiletry',
#   'bag',
#   'finally',
#   'hotel',
#   'heavy',
#   'traffic',
#   'time',
#   'weekend'],
#  ['friend',
#   'book',
#   'online',
#   'online',
#   'say',
#   'room',
#   'leave',
#   'book',
#   'show',
#   'hotel',
#   'receptionist',
#   'lady',
#   'turn',
#   'away',
#   'room',
#   'available',
#   'say',
#   'small',
#   'room',
#   'small',
#   'room',
#   'would',
#   'put',
#   'extra',
#   'bed',
#   'would',
#   'tight',
#   'look',
#   'accommodation',
#   'ask',
#   'cancel',
#   'reservation',
#   'charge',
#   'card',
#   'say',
#   'would',
#   'cancel',
#   'stay',
#   'night',
#   'hotel',
#   'card',
#   'still',
#   'get',
#   'charge',
#   'go',
#   'back',
#   'ask',
#   'stay',
#   'get',
#   'refund',
#   'night',
#   'suppose',
#   'reservation',
#   'come',
#   'office',
#   'card',
#   'charge',
#   'could',
#   'cancel',
#   'lady'],
#  ['stayed_night',
#   'aware',
#   'high',
#   'rating',
#   'hotel',
#   'agree',
#   'point',
#   'mention',
#   'clean',
#   'good',
#   'service',
#   'book',
#   'transportation',
#   'fast',
#   'efficient',
#   'however',
#   'room',
#   'small',
#   'put',
#   'stuff',
#   'closet',
#   'fast',
#   'internet',
#   'small',
#   'tv',
#   'english',
#   'channel',
#   'room',
#   'safe',
#   'visit',
#   'city',
#   'take',
#   'passport',
#   'money',
#   'privacy',
#   'also',
#   'question',
#   'shut',
#   'window',
#   'light',
#   'pass',
#   'would',
#   'see',
#   'room'],
#  ['bed_comfortable',
#   'bite',
#   'short',
#   'foot',
#   'almost',
#   'stick',
#   'bed',
#   'pillow',
#   'thin',
#   'stack',
#   'together',
#   'make',
#   'pillow',
#   'noisy',
#   'use',
#   'earplug',
#   'paint',
#   'bathroom',
#   'peel',
#   'old',
#   'miss',
#   'ring',
#   'hole',
#   'would',
#   'stay',
#   'everywhere',
#   'else',
#   'book',
#   'pay',
#   'night'],
#  ['book',
#   'printout',
#   'confirmation',
#   'arrive',
#   'tourist',
#   'shuttle',
#   'eve',
#   'soon',
#   'mention',
#   'hotel',
#   'name',
#   'driver',
#   'couple',
#   'front',
#   'book',
#   'hotel',
#   'day',
#   'prior',
#   'use',
#   'honor',
#   'think',
#   'bad',
#   'incident',
#   'wrong',
#   'manager',
#   'refuse',
#   'look',
#   'booking_com',
#   'printout',
#   'room',
#   'normally',
#   'problem',
#   'know',
#   'hotel',
#   'tend',
#   'full',
#   'time',
#   'even',
#   'one',
#   'room',
#   'charge',
#   'much',
#   'high',
#   'normal',
#   'rate',
#   'reason',
#   'book',
#   'advance',
#   'luckily',
#   'find'],
#  ['good',
#   'view',
#   'obligingly',
#   'spew',
#   'cloud',
#   'smoke',
#   'dust',
#   'breakfast',
#   'time',
#   'day',
#   'room',
#   'poor',
#   'lighting',
#   'window_opene',
#   'internal',
#   'street',
#   'rather',
#   'useless',
#   'main',
#   'problem',
#   'hotel',
#   'situation',
#   'long',
#   'way',
#   'minute',
#   'walk_centre',
#   'many',
#   'uneven',
#   'surface',
#   'pothole',
#   'route',
#   'dimly',
#   'light',
#   'street',
#   'dark',
#   'necessitate',
#   'taxi',
#   'ride',
#   'especially',
#   'concerned',
#   'safety',
#   'evening',
#   'go',
#   'town',
#   'tend',
#   'stay',
#   'return',
#   'tend',
#   'go_back',
#   'inconvenient',
#   'problem',
#   'breakfast',
#   'absolutely',
#   'disgusting',
#   'coffee',
#   'merely',
#   'poor',
#   'nearest'],
#  ['want',
#   'much',
#   'hotel',
#   'nice',
#   'place',
#   'price',
#   'point',
#   'hotel',
#   'quite',
#   'lovely',
#   'centrally_located',
#   'nice',
#   'garden',
#   'clean',
#   'fantastic',
#   'view',
#   'room',
#   'great',
#   'apart',
#   'soft',
#   'bed',
#   'breakfast',
#   'parking',
#   'site',
#   'inconvenient',
#   'square',
#   'min',
#   'shape',
#   'deal',
#   'would',
#   'overlook',
#   'fact',
#   'first',
#   'day',
#   'constant',
#   'clanging',
#   'bell',
#   'nearby',
#   'church',
#   'complaint',
#   'unfortunately',
#   'loud',
#   'bar',
#   'playing',
#   'music'],
#  ['hate',
#   'write',
#   'arrive',
#   'hotel',
#   'truly',
#   'beautiful',
#   'staff',
#   'lovely',
#   'food',
#   'stay',
#   'friend',
#   'travel',
#   'arrival',
#   'wake',
#   'cover',
#   'way',
#   'spend',
#   'vacation',
#   'horrible',
#   'hotel',
#   'ask',
#   'proof',
#   'provide',
#   'clothe',
#   'change',
#   'room',
#   'appreciate',
#   'bad',
#   'rented',
#   'room',
#   'next',
#   'night',
#   'take',
#   'quickly',
#   'check',
#   'wonderful',
#   'city',
#   'would',
#   'stay'],
#  ['discover',
#   'reservation',
#   'fall',
#   'gain',
#   'room',
#   'generous',
#   'sized',
#   'bathroom',
#   'roomy',
#   'parking',
#   'need',
#   'owner',
#   'lovely',
#   'people',
#   'hotel',
#   'within_walke',
#   'distance',
#   'la_merce',
#   'restaurant',
#   'internet',
#   'service',
#   'close'],
#  ['disappointment',
#   'hotel',
#   'start',
#   'fact',
#   'reservation',
#   'want',
#   'send',
#   'hotel',
#   'complaie',
#   'mention',
#   'day',
#   'exchange',
#   'mail',
#   'own',
#   'confirm',
#   'transfer',
#   'airport',
#   'hotel',
#   'take',
#   'know',
#   'come',
#   'say',
#   'reservation',
#   'end',
#   'gave_us',
#   'room',
#   'discover',
#   'dirty',
#   'noisy',
#   'place',
#   'commune',
#   'photo',
#   'web',
#   'site',
#   'end',
#   'trip',
#   'use',
#   'hotel',
#   'much',
#   'clean',
#   'comfortable',
#   'nicer',
#   'also',
#   'none',
#   'people',
#   'reception',
#   'train',
#   'idea',
#   'accept',
#   'payment'],
#  ['stay',
#   'previously',
#   'decide',
#   'book',
#   'upmarket',
#   'hotel',
#   'final',
#   'night',
#   'flight',
#   'hotel',
#   'decent',
#   'location',
#   'dirty',
#   'comfortable',
#   'compare',
#   'cheap',
#   'hotel',
#   'previously',
#   'stay',
#   'arrive',
#   'ask',
#   'sheet',
#   'change',
#   'due',
#   'dirty',
#   'stay',
#   'also',
#   'notice',
#   'mug',
#   'old',
#   'lipstick',
#   'towel',
#   'dirty',
#   'pillowcase',
#   'first',
#   'time',
#   'consider',
#   'use',
#   'sleep',
#   'bag',
#   'inner',
#   'sleep',
#   'bed',
#   'staff',
#   'offer',
#   'solution',
#   'problem',
#   'walkable',
#   'location',
#   'relevant',
#   'definitely',
#   'much_better',
#   'stay',
#   'clean'],
#  ['night',
#   'previous',
#   'visit',
#   'stay',
#   'hotel',
#   'time',
#   'try',
#   'book',
#   'single',
#   'room',
#   'online',
#   'discount',
#   'bring',
#   'price',
#   'night',
#   'gtq',
#   'include',
#   'additional',
#   'taxis',
#   'come',
#   'room',
#   'small',
#   'come',
#   'ensuite',
#   'daily',
#   'housekeeping',
#   'hot_shower',
#   'cable',
#   'tv',
#   'breakfast',
#   'room',
#   'excellent',
#   'value',
#   'gtq',
#   'worth',
#   'rack',
#   'rate',
#   'night',
#   'list',
#   'worth',
#   'night',
#   'include',
#   'breakfast',
#   'host',
#   'nice',
#   'people',
#   'comfy',
#   'probably',
#   'little',
#   'much',
#   'edge',
#   'town',
#   'centre',
#   'people',
#   'decent'],
#  ['book',
#   'young',
#   'male',
#   'attempt',
#   'charge',
#   'tell',
#   'breakfast',
#   'include',
#   'other',
#   'egg',
#   'include',
#   'non',
#   'included_breakfast',
#   'want',
#   'egg',
#   'check',
#   'tell',
#   'woman',
#   'nee',
#   'pay',
#   'breakfast',
#   'correct',
#   'say',
#   'breakfast_include',
#   'catch',
#   'previous',
#   'man',
#   'lie',
#   'otherwise',
#   'like',
#   'pay',
#   'top',
#   'dollar',
#   'peak',
#   'time',
#   'accept',
#   'visa',
#   'cash',
#   'believe',
#   'man',
#   'lie',
#   'breakfast'],
#  ['basic',
#   'hotel',
#   'staff',
#   'nice',
#   'friendly',
#   'location',
#   'slightly',
#   'fringe',
#   'street',
#   'light',
#   'bright',
#   'area',
#   'happen',
#   'bedroom',
#   'back',
#   'hotel',
#   'open_air',
#   'market',
#   'start',
#   'really',
#   'early',
#   'noisy',
#   'light',
#   'sleeper',
#   'otherwise',
#   'ok',
#   'look',
#   'cheap',
#   'clean',
#   'place',
#   'stay'],
#  ['make',
#   'reservation',
#   'ask',
#   'pay',
#   'hotel',
#   'night',
#   'charge',
#   'night',
#   'credit_card',
#   'week',
#   'week',
#   'ask',
#   'refund',
#   'waste',
#   'time',
#   'polite',
#   'whatsapp',
#   'end',
#   'take',
#   'money',
#   'twice',
#   'never',
#   'get',
#   'refund',
#   'thief',
#   'avoid',
#   'cost',
#   'bad',
#   'experience',
#   'ever'],
#  ['room',
#   'majority',
#   'share',
#   'many',
#   'super',
#   'small',
#   'toilet',
#   'careful',
#   'price',
#   'quote',
#   'online',
#   'add',
#   'tourist',
#   'tax',
#   'represent',
#   'budget',
#   'hotel',
#   'experience',
#   'quality',
#   'definitely',
#   'high',
#   'hostel'],
#  ['hotel',
#   'bad',
#   'cute',
#   'style',
#   'room',
#   'decent',
#   'clean',
#   'linen',
#   'towel',
#   'wifi',
#   'water',
#   'lukewarm',
#   'gorgeous',
#   'location',
#   'pretty',
#   'good',
#   'quiet',
#   'place',
#   'stay',
#   'big',
#   'issue',
#   'put',
#   'room',
#   'night',
#   'room',
#   'occupy',
#   'need',
#   'move',
#   'next',
#   'night',
#   'room',
#   'able',
#   'fit',
#   'bed',
#   'large',
#   'group',
#   'huge',
#   'inconvenience',
#   'plan',
#   'well',
#   'could',
#   'avoid',
#   'otherwise',
#   'pretty',
#   'cute',
#   'place'],
#  ['first',
#   'good',
#   'common',
#   'space',
#   'nice',
#   'enough',
#   'staff_friendly',
#   'bed',
#   'ok',
#   'great',
#   'noise',
#   'shower',
#   'cleanliness',
#   'could',
#   'spend',
#   'little',
#   'add',
#   'fresh',
#   'paint',
#   'curtain',
#   'need',
#   'clean',
#   'place',
#   'old',
#   'run'],
#  ['room',
#   'invite',
#   'relax',
#   'want',
#   'room',
#   'sleep',
#   'fine',
#   'share',
#   'space',
#   'nice',
#   'balcony',
#   'watch',
#   'firework',
#   'amazing',
#   'kind',
#   'although',
#   'mix',
#   'online',
#   'payment',
#   'result',
#   'take',
#   'quetzale',
#   'later',
#   'need',
#   'room',
#   'push',
#   'wall',
#   'quite',
#   'cramped',
#   'even',
#   'couple',
#   'window',
#   'appear',
#   'storage',
#   'area',
#   'cleaning',
#   'supply',
#   'mean',
#   'get',
#   'hear',
#   'lot',
#   'morning',
#   'conversation',
#   'housekeeping',
#   'staff',
#   'hallway',
#   'pretty',
#   'loud',
#   'seem',
#   'room',
#   'exterior',
#   'window',
#   'glad'],
#  ['advertise',
#   'hotel',
#   'euro_maya',
#   'suite',
#   'real',
#   'name',
#   'hotel',
#   'select',
#   'hotel',
#   'due',
#   'nice',
#   'review',
#   'read',
#   'question',
#   'review',
#   'real',
#   'people',
#   'opinion',
#   'service',
#   'kind',
#   'crazy',
#   'standard',
#   'high',
#   'hotel',
#   'website',
#   'picture',
#   'well',
#   'do',
#   'real',
#   'hotel',
#   'totally',
#   'different',
#   'form',
#   'reality',
#   'pay',
#   'dollar',
#   'night',
#   'quetzal',
#   'breakfast_include',
#   'room',
#   'terrible',
#   'poor',
#   'clean',
#   'nasty',
#   'towel',
#   'really',
#   'old',
#   'almost',
#   'useless',
#   'location',
#   'far',
#   'central_square',
#   'convenience',
#   'location',
#   'review',
#   'say',
#   'love',
#   'cultural',
#   'site',
#   'many',
#   'thing',
#   'learn',
#   'colonial',
#   'time'],
#  ['euro_maya',
#   'nice',
#   'small',
#   'hotel',
#   'staff_friendly',
#   'helpful',
#   'room',
#   'clean',
#   'breakfast',
#   'thing',
#   'go',
#   'roof_top',
#   'terrace',
#   'great',
#   'spot',
#   'breakfast',
#   'enjoy',
#   'volcano',
#   'view',
#   'block',
#   'central_park',
#   'look',
#   'posh',
#   'place',
#   'top',
#   'line',
#   'sheet',
#   'towel',
#   'service',
#   'look',
#   'clean',
#   'friendly',
#   'affordable',
#   'place',
#   'lie',
#   'head',
#   'fit',
#   'bill'],
#  ['book',
#   'return',
#   'mainly',
#   'mistakenly',
#   'list',
#   'book',
#   'hotel',
#   'fact',
#   'hotel',
#   'travel_agency',
#   'happen',
#   'rent',
#   'room',
#   'could',
#   'tell',
#   'property',
#   'sign',
#   'location',
#   'superb',
#   'problem',
#   'disgraceful',
#   'service',
#   'begin',
#   'even',
#   'step',
#   'foot',
#   'hotel',
#   'charge',
#   'issue',
#   'get',
#   'lousy',
#   'ask',
#   'arrive',
#   'suppose',
#   'check',
#   'time',
#   'complain',
#   'talk',
#   'policy',
#   'mention',
#   'employee',
#   'suppose',
#   'probably',
#   'could',
#   'hardly',
#   'speak'],
#  ['birthday',
#   'celebration',
#   'book',
#   'hotel',
#   'think',
#   'centrally_locate',
#   'price',
#   'ok',
#   'hotel',
#   'locate',
#   'town',
#   'central',
#   'accessible',
#   'offer',
#   'parking',
#   'blocks_away',
#   'bad',
#   'thing',
#   'hotel',
#   'locate',
#   'next',
#   'alliance',
#   'weekend',
#   'stay',
#   'concert',
#   'bad',
#   'concert',
#   'last',
#   'ask',
#   'watchman',
#   'call',
#   'police',
#   'aware',
#   'pm',
#   'manager',
#   'leave',
#   'close',
#   'door',
#   'assist',
#   'also',
#   'establishment',
#   'sure',
#   'bar',
#   'restaurant',
#   'hotel',
#   'group',
#   'noisy',
#   'people',
#   'come',
#   'go',
#   'night',
#   'long',
#   'sleep',
#   'horrible'],
#  ['stay',
#   'first',
#   'hotel',
#   'full',
#   'last_night',
#   'stay',
#   'place',
#   'sorry',
#   'state',
#   'disrepair',
#   'look',
#   'unloved',
#   'room',
#   'general',
#   'appearance',
#   'bite',
#   'shabby',
#   'one',
#   'hotel',
#   'entire',
#   'town',
#   'full',
#   'big',
#   'event',
#   'service',
#   'obvious',
#   'place',
#   'seem',
#   'spooky',
#   'luckily',
#   'good',
#   'conscience',
#   'can',
#   'recommend'],
#  ['hotel',
#   'room',
#   'nice',
#   'wife',
#   'get',
#   'room',
#   'thing',
#   'bathroom',
#   'really',
#   'small',
#   'flush',
#   'toilet',
#   'water_pressure',
#   'super',
#   'super',
#   'slow',
#   'bathroom',
#   'toilet',
#   'really',
#   'small',
#   'nee',
#   'leave',
#   'use',
#   'really',
#   'important',
#   'party',
#   'super',
#   'cool',
#   'door',
#   'lot',
#   'people',
#   'visit',
#   'socialize',
#   'sleep',
#   'early',
#   'energize',
#   'tour',
#   'good',
#   'place',
#   'stay',
#   'noise',
#   'end',
#   'costumer',
#   'service',
#   'really',
#   'amazing',
#   'really',
#   'enjoy',
#   'service'],
#  ['stayed_night',
#   'hotel',
#   'could',
#   'sleep',
#   'staff_friendly',
#   'unfortunately',
#   'complain',
#   'noise',
#   'clock',
#   'evening',
#   'noise',
#   'movement',
#   'room',
#   'also',
#   'unlucky',
#   'client',
#   'hotel',
#   'care',
#   'client',
#   'want',
#   'sleep',
#   'recommend',
#   'hotel',
#   'want',
#   'peace',
#   'quiet'],
#  ['first',
#   'positive',
#   'hotel',
#   'look',
#   'great',
#   'ground',
#   'credit',
#   'team',
#   'responsible',
#   'location',
#   'restaurant',
#   'overlook',
#   'active',
#   'volcano',
#   'spectacular',
#   'imagine',
#   'dinner',
#   'backdrop',
#   'lava',
#   'spout',
#   'volcano',
#   'probably',
#   'daily',
#   'event',
#   'lucky',
#   'hotel',
#   'however',
#   'well',
#   'let',
#   'room',
#   'clean',
#   'lack_air',
#   'would',
#   'therefore',
#   'expect',
#   'able',
#   'ventilate',
#   'open',
#   'window',
#   'insect',
#   'screen',
#   'sensible',
#   'result',
#   'stuffy',
#   'room',
#   'room',
#   'also',
#   'room',
#   'safe',
#   'guest',
#   'place',
#   'valuable',
#   'security',
#   'box',
#   'reception',
#   'traveller',
#   'carry',
#   'tablet',
#   'laptop',
#   'camera',
#   'phone',
#   'suitable',
#   'practical',
#   'really',
#   'good',
#   'enough'],
#  ['lovely',
#   'position',
#   'nice',
#   'room',
#   'glad',
#   'courtyard',
#   'people',
#   'breakfast',
#   'right_outside',
#   'bedroom',
#   'window',
#   'sad',
#   'poor',
#   'attitude',
#   'staff',
#   'water',
#   'ration',
#   'attempt',
#   'offer',
#   'filtered_water',
#   'tea',
#   'service',
#   'room',
#   'morning',
#   'tea',
#   'fine',
#   'undrinkable',
#   'manager',
#   'provide',
#   'maybe',
#   'lack',
#   'also',
#   'good',
#   'enough',
#   'way',
#   'charge',
#   'effort',
#   'make',
#   'resolve',
#   'problem',
#   'plastic',
#   'flower',
#   'petal',
#   'towel',
#   'really',
#   'bother',
#   'turn',
#   'service',
#   'dirty',
#   'towel',
#   'cup',
#   'leave',
#   'night',
#   'would',
#   'call',
#   'average',
#   'hotel',
#   'label'],
#  ['stay',
#   'book',
#   'pay',
#   'cash',
#   'check',
#   'month',
#   'later',
#   'notice',
#   'charge',
#   'visa',
#   'card',
#   'well',
#   'refuse',
#   'refund',
#   'many',
#   'better_option',
#   'well',
#   'price',
#   'steer',
#   'clear'],
#  ['provide',
#   'bed',
#   'average',
#   'price',
#   'location',
#   'rather',
#   'decent',
#   'want',
#   'rather',
#   'problem',
#   'cold',
#   'night',
#   'quite',
#   'strong',
#   'smell',
#   'disinfectant',
#   'time',
#   'least',
#   'tell',
#   'cleaning',
#   'occur',
#   'little',
#   'way',
#   'social',
#   'atmosphere',
#   'certainly',
#   'lack',
#   'kind',
#   'usefulness',
#   'warmth',
#   'staff',
#   'friendly',
#   'knowledgeable',
#   'town',
#   'transport',
#   'importantly',
#   'stay',
#   'begin',
#   'suffer',
#   'virus',
#   'hostel',
#   'fault',
#   'concern',
#   'bed',
#   'several',
#   'day',
#   'moan',
#   'look',
#   'dreadful',
#   'staff',
#   'walk',
#   'past',
#   'unconcerned',
#   'would',
#   'value',
#   'social',
#   'responsibility'],
#  ['arrive',
#   'reserve',
#   'advance',
#   'room',
#   'show',
#   'picture',
#   'even',
#   'window',
#   'place',
#   'dirty',
#   'smell',
#   'damp',
#   'staff',
#   'insist',
#   'pay',
#   'full',
#   'amount',
#   'offer',
#   'use',
#   'try',
#   'resolve',
#   'problem',
#   'terrible',
#   'room',
#   'terrible',
#   'customer_service'],
#  ['stay',
#   'three_night',
#   'unfortunately',
#   'room',
#   'small',
#   'appear',
#   'picture',
#   'stuffy',
#   'air',
#   'keep',
#   'staircase',
#   'staff_friendly',
#   'enough',
#   'seem',
#   'bit',
#   'work',
#   'often',
#   'let',
#   'night',
#   'ring',
#   'clean',
#   'enough',
#   'decent',
#   'location',
#   'decent',
#   'shower',
#   'pretty',
#   'nice',
#   'upstairs',
#   'courtyard',
#   'place',
#   'offer',
#   'well',
#   'value_money',
#   'elsewhere'],
#  ['receptionist',
#   'provide',
#   'little',
#   'information',
#   'detail',
#   'hotel',
#   'prompt',
#   'room',
#   'clean',
#   'hear',
#   'may',
#   'make',
#   'noise',
#   'fan',
#   'hot',
#   'hot',
#   'breakfast_include',
#   'rate',
#   'say',
#   'hotel',
#   'confirmation',
#   'ask',
#   'staff',
#   'really',
#   'problem',
#   'meh',
#   'would',
#   'probably',
#   'next',
#   'time',
#   'deserve',
#   'well',
#   'experience'],
#  ['room',
#   'small',
#   'box',
#   'ventilation',
#   'even',
#   'fan',
#   'get',
#   'tiny',
#   'courtyard',
#   'view',
#   'shower',
#   'get',
#   'turn',
#   'water',
#   'periodically',
#   'night',
#   'say',
#   'staff',
#   'generally',
#   'nice',
#   'good',
#   'make',
#   'stay',
#   'pleasant',
#   'evening',
#   'flight',
#   'staff',
#   'keep',
#   'bag',
#   'hotel',
#   'checkout',
#   'luxury',
#   'place',
#   'decent',
#   'location',
#   'need',
#   'place',
#   'crash',
#   'may',
#   'ok',
#   'visit',
#   'thankfully',
#   'cold',
#   'night',
#   'imagine',
#   'would',
#   'impossible_sleep',
#   'temperature',
#   'hotter'],
#  ['people',
#   'nice',
#   'desk',
#   'get',
#   'fool',
#   'picture',
#   'window',
#   'window',
#   'give',
#   'hallway',
#   'noisy',
#   'lack',
#   'lousy',
#   'internet',
#   'bad',
#   'location',
#   'good',
#   'repeat'],
#  ['price',
#   'decent',
#   'value',
#   'screen',
#   'mosquiro',
#   'wake',
#   'night',
#   'onsite',
#   'bar',
#   'room',
#   'noisy',
#   'fan',
#   'room',
#   'turn',
#   'drip',
#   'night',
#   'stay',
#   'never'],
#  ['nice',
#   'decoration',
#   'terrace',
#   'overcharge',
#   'convert',
#   'price',
#   'currency',
#   'push',
#   'consume',
#   'difference',
#   'hotel',
#   'service',
#   'poor',
#   'price',
#   'pay',
#   'give_us',
#   'towel',
#   'clean',
#   'table',
#   'breakfast',
#   'also',
#   'book',
#   'morning',
#   'really',
#   'unfriendly',
#   'make',
#   'feel',
#   'unwelcome',
#   'would',
#   'never',
#   'come_back',
#   'place',
#   'money',
#   'pay',
#   'good',
#   'hostel',
#   'sure',
#   'attend',
#   'well'],
#  ['locate',
#   'site',
#   'middle',
#   'restaurant',
#   'shop',
#   'bar',
#   'view',
#   'balcony',
#   'breathtake',
#   'complaint',
#   'breakfast',
#   'fry',
#   'egg',
#   'toast',
#   'bean',
#   'think',
#   'well',
#   'even',
#   'guest',
#   'pay'],
#  ['nice',
#   'decor',
#   'breakfast_include',
#   'courtyard',
#   'sit',
#   'blanket',
#   'ask',
#   'little',
#   'wifi',
#   'drop',
#   'stay',
#   'room',
#   'reception',
#   'busy',
#   'road',
#   'bus',
#   'lorry',
#   'wake'],
#  ['room',
#   'small',
#   'clean',
#   'dusty',
#   'bed',
#   'uncomfortable',
#   'hardly',
#   'shower'],
#  ['pretty',
#   'really',
#   'cute',
#   'spacious',
#   'room',
#   'staff',
#   'nice',
#   'hotel',
#   'safe',
#   'quiet',
#   'downside',
#   'central',
#   'area',
#   'day',
#   'recommend',
#   'walk',
#   'night',
#   'plan',
#   'late',
#   'evening',
#   'recommend_staye',
#   'little',
#   'close',
#   'central',
#   'area',
#   'close',
#   'really',
#   'loud',
#   'even'],
#  ['book',
#   'afterwards',
#   'find',
#   'hotel',
#   'much',
#   'low',
#   'rate',
#   'expedia',
#   'would',
#   'cancel',
#   'first',
#   'hotel',
#   'room',
#   'show',
#   'extraordinary',
#   'usd_p',
#   'day',
#   'dark',
#   'dingy',
#   'bath',
#   'view',
#   'express',
#   'dismay',
#   'price',
#   'offer',
#   'move',
#   'upstairs',
#   'nice',
#   'room',
#   'breakfast',
#   'consist',
#   'coffee',
#   'toast',
#   'egg',
#   'refrie',
#   'bean',
#   'little_bit',
#   'cheese',
#   'complain',
#   'lack',
#   'fruit',
#   'monotony',
#   'menu',
#   'daily',
#   'arrive',
#   'take'],
#  ['say',
#   'hotel',
#   'nice',
#   'breakfast',
#   'splendid',
#   'view',
#   'terrace',
#   'unfortunately',
#   'room',
#   'one',
#   'wait',
#   'standard',
#   'room',
#   'book',
#   'tiny',
#   'sqm',
#   'advertise',
#   'sqm',
#   'suite',
#   'book',
#   'double',
#   'price',
#   'normal',
#   'room',
#   'sure',
#   'separate',
#   'bed',
#   'advertise',
#   'booking',
#   'site',
#   'separate',
#   'bed',
#   'suite',
#   'consider',
#   'public',
#   'seating',
#   'place',
#   'part',
#   'room',
#   'indeed',
#   'arriving_late',
#   'hotel',
#   'reason',
#   'give_us',
#   'leftover',
#   'book',
#   'month',
#   'advance'],
#  ['pro',
#   'friendly',
#   'staff',
#   'good',
#   'price',
#   'con',
#   'room',
#   'street',
#   'noisy',
#   'bring',
#   'sleep',
#   'medication',
#   'noise',
#   'continue',
#   'midnight',
#   'start',
#   'also',
#   'able',
#   'hear_people',
#   'room',
#   'breakfast',
#   'morning',
#   'toast',
#   'jam',
#   'fruit',
#   'next_morning',
#   'egg',
#   'fruit',
#   'third',
#   'morning',
#   'decide',
#   'go',
#   'restaurant',
#   'substantial',
#   'breakfast',
#   'give',
#   'coffee',
#   'produce',
#   'country',
#   'expect',
#   'good',
#   'coffee',
#   'morning',
#   'bad',
#   'coffee',
#   'ever',
#   'watery',
#   'weak'],
#  ['location',
#   'hotel',
#   'staff',
#   'make',
#   'feel',
#   'welcome',
#   'breakfast',
#   'nice',
#   'breakfast',
#   'fresh',
#   'fruit',
#   'room',
#   'spacious',
#   'dislike',
#   'super',
#   'thin_wall',
#   'hear',
#   'everything_goe',
#   'include',
#   'extracurricular',
#   'activity',
#   'include',
#   'music',
#   'could',
#   'provide',
#   'face',
#   'towel',
#   'verdict',
#   'hotel',
#   'get',
#   'endorsement',
#   'location',
#   'price',
#   'however',
#   'mindful',
#   'super',
#   'thin',
#   'paper',
#   'wall',
#   'hear',
#   'thing',
#   'want',
#   'hear'],
#  ['good',
#   'pool',
#   'nice',
#   'room',
#   'mattress',
#   'room',
#   'terrible',
#   'room',
#   'number',
#   'wor',
#   'thing',
#   'small',
#   'hotel',
#   'service',
#   'people',
#   'rude',
#   'even',
#   'look',
#   'face',
#   'never',
#   'ever',
#   'say',
#   'good',
#   'morning',
#   'incredible',
#   'small',
#   'hotel',
#   'can',
#   'train',
#   'employee',
#   'properly',
#   'hard',
#   'say',
#   'good',
#   'morning',
#   'never',
#   'back'],
#  ['somewhere',
#   'online',
#   'first',
#   'sure',
#   'last',
#   'time',
#   'check',
#   'write',
#   'already',
#   'hotel',
#   'massively',
#   'loud',
#   'fairness',
#   'ridiculous',
#   'loud',
#   'apart',
#   'standard',
#   'room',
#   'tiny',
#   'wardrobe',
#   'replace',
#   'toilet',
#   'shower',
#   'aware'],
#  ['staff',
#   'wonderful',
#   'girl',
#   'desk',
#   'could',
#   'helpful',
#   'horribly',
#   'noisy',
#   'place',
#   'stay',
#   'intermittent',
#   'machinery',
#   'noise',
#   'night',
#   'due',
#   'courtyard',
#   'also',
#   'room',
#   'courtyard_garden',
#   'people',
#   'sit',
#   'talk',
#   'noisy',
#   'night',
#   'room',
#   'nice',
#   'seem',
#   'better_place',
#   'stay'],
#  ['plus_side',
#   'hotel',
#   'conveniently_locate',
#   'many',
#   'business',
#   'around',
#   'keep',
#   'clean',
#   'employee',
#   'try',
#   'make',
#   'feel',
#   'good',
#   'negative',
#   'side',
#   'room',
#   'pack',
#   'small',
#   'location',
#   'easily',
#   'hear',
#   'outside',
#   'noise',
#   'night',
#   'get',
#   'late',
#   'listen',
#   'say',
#   'coffee',
#   'maker',
#   'room',
#   'keep',
#   'make',
#   'noise',
#   'night',
#   'recommend',
#   'place'],
#  ['room',
#   'really',
#   'small',
#   'lady',
#   'really',
#   'rude',
#   'family',
#   'good',
#   'think',
#   'boy',
#   'stay',
#   'night',
#   'rest',
#   'enjoy',
#   'time'],
#  ['always',
#   'come',
#   'hotel',
#   'day',
#   'service',
#   'change',
#   'alot',
#   'feel',
#   'welcome',
#   'price',
#   'change',
#   'well',
#   'month',
#   'thing',
#   'make',
#   'sence',
#   'room',
#   'people',
#   'room',
#   'people',
#   'choice'],
#  ['bad',
#   'definitely',
#   'top',
#   'notch',
#   'entire',
#   'week',
#   'free_wifi',
#   'terrible',
#   'often',
#   'cut',
#   'weak',
#   'signal',
#   'bed',
#   'ask',
#   'extra',
#   'pillow',
#   'say',
#   'thin_hear',
#   'neighbor',
#   'talk',
#   'sneeze',
#   'use',
#   'restroom',
#   'place',
#   'price',
#   'high',
#   'quality',
#   'staff',
#   'always',
#   'friendly',
#   'stay'],
#  ['room',
#   'room',
#   'large',
#   'bathroom',
#   'bed',
#   'firm',
#   'room',
#   'dark',
#   'comfortable',
#   'fridge',
#   'mini',
#   'bar',
#   'kettle',
#   'make',
#   'staff_friendly',
#   'helpful',
#   'especially',
#   'work',
#   'restaurant',
#   'give',
#   'exceptional',
#   'service',
#   'breakfast_include',
#   'stay',
#   'standard',
#   'victor',
#   'really',
#   'great',
#   'try',
#   'restaurant',
#   'food',
#   'average',
#   'room',
#   'overlook',
#   'beautiful',
#   'garden',
#   'ground',
#   'room',
#   'clean',
#   'room',
#   'story',
#   'walk',
#   'early_morne'],
#  ['cute',
#   'charming',
#   'staff',
#   'kind',
#   'professional',
#   'helpful',
#   'perk',
#   'hotel',
#   'breakfast_include',
#   'use',
#   'amenity',
#   'hotel',
#   'stay',
#   'daughter',
#   'upper',
#   'terrace',
#   'room',
#   'sadly',
#   'rough',
#   'night',
#   'sleep',
#   'noise',
#   'street',
#   'notify',
#   'beforehand',
#   'receptionist',
#   'agree',
#   'noisy',
#   'room',
#   'complaint',
#   'common',
#   'disappointed',
#   'value',
#   'room',
#   'lack',
#   'rest',
#   'perhaps',
#   'stay',
#   'room',
#   'bottom',
#   'floor',
#   'back',
#   'would',
#   'pleasant',
#   'experience'],
#  ['last_night',
#   'try',
#   'come',
#   'assume',
#   'drunk',
#   'get',
#   'room',
#   'girl',
#   'touch',
#   'inappropriately',
#   'ask',
#   'leave',
#   'minute',
#   'try',
#   'come',
#   'back',
#   'additional',
#   'guy',
#   'get',
#   'room',
#   'eventually',
#   'give',
#   'horrible',
#   'experience',
#   'specially',
#   'overnight',
#   'guard'],
#  ['arrive',
#   'hotel',
#   'early',
#   'start',
#   'long',
#   'travel',
#   'tell',
#   'immediately',
#   'room',
#   'due',
#   'overbooking',
#   'room',
#   'reserve',
#   'pay',
#   'full',
#   'least',
#   'month',
#   'previous',
#   'tell',
#   'upgrade',
#   'property',
#   'euro_maya',
#   'suite',
#   'room',
#   'nicer',
#   'apparently',
#   'quick',
#   'check',
#   'online',
#   'find',
#   'stay',
#   'euro_maya',
#   'suite',
#   'indeed',
#   'little_bit',
#   'expensive',
#   'reason',
#   'book',
#   'euro_maya',
#   'location',
#   'rooftop_terrace',
#   'girl_reception',
#   'nice',
#   'small',
#   'discount',
#   'excursion',
#   'room',
#   'suite',
#   'lovely',
#   'room',
#   'great',
#   'time'],
#  ['stayed_night',
#   'change',
#   'book',
#   'apparently',
#   'issue',
#   'room',
#   'other',
#   'available',
#   'move',
#   'nice',
#   'spacious',
#   'triple',
#   'room',
#   'double',
#   'single',
#   'fan',
#   'evening',
#   'fan',
#   'adequate',
#   'room',
#   'get',
#   'quite',
#   'stuffy',
#   'open',
#   'window',
#   'whenever',
#   'room',
#   'air',
#   'shower',
#   'would',
#   'quickly',
#   'lose',
#   'still',
#   'good',
#   'pressure',
#   'various',
#   'receptionist',
#   'see',
#   'night',
#   'speak',
#   'little',
#   'luckily',
#   'really',
#   'nee',
#   'speak',
#   'much',
#   'breakfast_include',
#   'head',
#   'food',
#   'slow',
#   'occasionally'],
#  ['pro',
#   'fantastic',
#   'location',
#   'nice',
#   'courtyard',
#   'kitchen',
#   'great',
#   'could',
#   'make',
#   'breakfast',
#   'con',
#   'unfortunately',
#   'none',
#   'really',
#   'matter',
#   'wall',
#   'hotel',
#   'room',
#   'thin',
#   'barely',
#   'sleep',
#   'guest',
#   'hotel',
#   'night',
#   'clearly',
#   'impossible',
#   'awoken',
#   'finally_got',
#   'quiet',
#   'noise',
#   'start',
#   'guest',
#   'wake',
#   'presumably',
#   'early_morne',
#   'pick',
#   'up',
#   'hike',
#   'expensive',
#   'fail',
#   'provide',
#   'decent',
#   'sleep',
#   'addition',
#   'wifi',
#   'really',
#   'poor',
#   'time',
#   'finally',
#   'provide',
#   'free_coffee',
#   'coffee',
#   'rubbish',
#   'cup',
#   'taste',
#   'chlorine',
#   'small',
#   'thing',
#   'generally',
#   'really',
#   'disappointing'],
#  ['stay',
#   'week',
#   'solo',
#   'female',
#   'traveler',
#   'positive',
#   'hotel',
#   'apartment',
#   'photo',
#   'nice',
#   'look',
#   'cozy',
#   'housekeeping',
#   'good',
#   'never',
#   'come',
#   'say',
#   'come',
#   'security',
#   'beds_comfortable',
#   'good',
#   'safe',
#   'room',
#   'great',
#   'sure',
#   'could',
#   'fit',
#   'full',
#   'sized',
#   'lap',
#   'top',
#   'pad',
#   'perfect',
#   'wireless',
#   'access',
#   'pretty',
#   'reliable',
#   'even',
#   'lose',
#   'access',
#   'quickly',
#   'negative',
#   'noisy',
#   'side',
#   'okay',
#   'otherwise',
#   'hear_everythe',
#   'several_time',
#   'people',
#   'party',
#   'quite',
#   'loudly',
#   'go',
#   'speak',
#   'speak',
#   'tenant',
#   'change'],
#  ['second',
#   'time',
#   'come',
#   'back',
#   'recent',
#   'experience',
#   'hotel',
#   'barely',
#   'space',
#   'bag',
#   'book',
#   'triple',
#   'room',
#   'book',
#   'room',
#   'price',
#   'dollar',
#   'night',
#   'eve',
#   'good_location',
#   'many_restaurant',
#   'friendly',
#   'staff',
#   'however',
#   'try',
#   'good',
#   'understand',
#   'room',
#   'upper',
#   'floor',
#   'housekeeping',
#   'room',
#   'night',
#   'hear',
#   'laundry',
#   'machine',
#   'turn',
#   'bother',
#   'good',
#   'sleeper',
#   'room',
#   'mold',
#   'ceile',
#   'good',
#   'free_wifi',
#   'bathroom',
#   'small',
#   'clean',
#   'difficult',
#   'regulate',
#   'shower',
#   'airport',
#   'pick',
#   'book'],
#  ['secure',
#   'centrally_locate',
#   'beds_comfortable',
#   'cleanliness',
#   'sheet',
#   'questionable',
#   'stain',
#   'hair',
#   'window',
#   'room',
#   'look',
#   'garden',
#   'common',
#   'space',
#   'airflow',
#   'room',
#   'limited',
#   'fan',
#   'provide',
#   'water_pressure',
#   'good',
#   'day',
#   'next_day',
#   'run',
#   'water',
#   'sure',
#   'freak',
#   'accident',
#   'common',
#   'occurrence',
#   'hour',
#   'job',
#   'memorable'],
#  ['share',
#   'room',
#   'bed',
#   'clean',
#   'basic',
#   'bathroom',
#   'tight',
#   'fit',
#   'mirror',
#   'turn',
#   'pressure',
#   'high',
#   'staff',
#   'kind',
#   'accommodate',
#   'ask',
#   'move',
#   'room',
#   'downstairs',
#   'carry',
#   'luggage',
#   'narrow',
#   'stair',
#   'enough',
#   'place',
#   'eat',
#   'shop',
#   'great',
#   'walking',
#   'everywhere'],
#  ['bad',
#   'allow',
#   'audio',
#   'upload',
#   'review',
#   'owner',
#   'place',
#   'make',
#   'much',
#   'noise',
#   'night',
#   'talk',
#   'loud',
#   'courtyard',
#   'listen',
#   'want',
#   'good',
#   'night',
#   'rest',
#   'look'],
#  ['big',
#   'disappointment',
#   'see',
#   'room',
#   'think',
#   'nice',
#   'close',
#   'inspection',
#   'soon',
#   'realise',
#   'place',
#   'dirty',
#   'hotel',
#   'make',
#   'look',
#   'nice',
#   'painting',
#   'wall',
#   'add',
#   'mood',
#   'light',
#   'nice',
#   'design',
#   'bed',
#   'sheet',
#   'take',
#   'nice',
#   'photo',
#   'see',
#   'fb',
#   'page',
#   'reality',
#   'room',
#   'dirty',
#   'looked_like',
#   'floor',
#   'clean',
#   'long_time',
#   'bathroom',
#   'also',
#   'bad',
#   'eventually',
#   'bite',
#   'warm',
#   'still',
#   'freeze',
#   'shower',
#   'also',
#   'noisy',
#   'main',
#   'street',
#   'room',
#   'furthest',
#   'away',
#   'talk',
#   'reception',
#   'noise',
#   'amplify',
#   'design',
#   'hotel',
#   'door',
#   'come',
#   'back',
#   'late',
#   'hear',
#   'loudly',
#   'corner'],
#  ['pro',
#   'beautiful',
#   'hotel',
#   'contra',
#   'horrible',
#   'check',
#   'experience',
#   'inflexible',
#   'policy',
#   'inform',
#   'arrival',
#   'solve',
#   'problem',
#   'hotel',
#   'beautiful',
#   'keep',
#   'mind',
#   'problem',
#   'nightmare',
#   'try',
#   'solve'],
#  ['large',
#   'clean',
#   'room',
#   'room',
#   'side',
#   'colorful',
#   'courtyard',
#   'lobby',
#   'staff',
#   'carry',
#   'luggage',
#   'hotel',
#   'garden',
#   'full',
#   'plant',
#   'flower',
#   'well',
#   'arrange',
#   'regular',
#   'breakfast',
#   'waiter',
#   'service',
#   'need',
#   'improvement'],
#  ['hard',
#   'wife',
#   'take',
#   'could',
#   'sleep',
#   'hard',
#   'double',
#   'lucky',
#   'endure',
#   'multiple',
#   'bed',
#   'bug',
#   'bite',
#   'get',
#   'away',
#   'still',
#   'itch',
#   'write',
#   'promise',
#   'room',
#   'size',
#   'thimble',
#   'great',
#   'staff',
#   'sort',
#   'next_day',
#   'thank',
#   'roof_top',
#   'great',
#   'breakfast',
#   'kitchen',
#   'good',
#   'basic',
#   'meal',
#   'good',
#   'price'],
#  ['overall',
#   'hotel',
#   'nice',
#   'service',
#   'great',
#   'however',
#   'want',
#   'iin',
#   'room',
#   'right',
#   'courtyard',
#   'use',
#   'breakfast',
#   'set',
#   'start',
#   'also',
#   'visitor',
#   'arrive',
#   'leave',
#   'night',
#   'wake',
#   'also',
#   'room',
#   'window',
#   'hotel',
#   'toilet',
#   'open',
#   'bathroom',
#   'noise',
#   'use',
#   'overnight',
#   'finally',
#   'live',
#   'rock',
#   'band',
#   'play',
#   'pub',
#   'effectively',
#   'side',
#   'wall',
#   'room',
#   'ask',
#   'move',
#   'tell',
#   'suitable',
#   'room',
#   'available',
#   'clearly',
#   'untrue',
#   'saw',
#   'room',
#   'come',
#   'go',
#   'suitable',
#   'quite',
#   'location',
#   'hotel',
#   'say',
#   'room'],
#  ['made_reservation',
#   'location',
#   'list',
#   'locate',
#   'arrive',
#   'gentleman',
#   'tell',
#   'driver',
#   'take',
#   'location',
#   'decent',
#   'location',
#   'bathroom',
#   'nice',
#   'breakfast',
#   'good',
#   'well',
#   'comfortable',
#   'frustration',
#   'location',
#   'want',
#   'center',
#   'charming'],
#  ['confusion',
#   'get',
#   'think',
#   'book',
#   'euro_maya',
#   'suite',
#   'end',
#   'location',
#   'call',
#   'confirm',
#   'fine',
#   'room',
#   'pretty',
#   'cramped',
#   'big',
#   'issue',
#   'ac',
#   'also',
#   'overhead',
#   'fan',
#   'hotel',
#   'fan',
#   'bring',
#   'stuff',
#   'even',
#   'leave',
#   'breeze',
#   'really',
#   'stuffy',
#   'nice',
#   'breakfast',
#   'roof',
#   'breakfast',
#   'super',
#   'plentiful',
#   'serve',
#   'lovely',
#   'staff',
#   'location',
#   'top'],
#  ['gorgeous',
#   'spacious',
#   'room',
#   'nice',
#   'breakfast_include',
#   'day',
#   'complimentary',
#   'coffee_tea',
#   'purify',
#   'water',
#   'convenient',
#   'centrally_locate',
#   'unfortunately',
#   'shower',
#   'water',
#   'cold',
#   'let',
#   'know',
#   'plan',
#   'return',
#   'late_night',
#   'lock',
#   'use',
#   'door',
#   'call',
#   'exhaust',
#   'find',
#   'alternate',
#   'accommodation',
#   'middle_night',
#   'explain',
#   'staff',
#   'next_morne',
#   'refund',
#   'fee',
#   'night'],
#  ['night',
#   'way',
#   'service',
#   'trip',
#   'location_close',
#   'market',
#   'square',
#   'concrete',
#   'design',
#   'wall',
#   'noise',
#   'would',
#   'travel',
#   'stairwell',
#   'night',
#   'long',
#   'lot',
#   'stay',
#   'seam',
#   'care',
#   'hot',
#   'much',
#   'noise',
#   'make',
#   'night',
#   'long',
#   'room',
#   'sparsely',
#   'decorate',
#   'could',
#   'use',
#   'upgrade',
#   'bed',
#   'bedding',
#   'pillow',
#   'public',
#   'area',
#   'pretty',
#   'wifi',
#   'work',
#   'room',
#   'area',
#   'stay'],
#  ['spend',
#   'would',
#   'return',
#   'downstairs',
#   'room',
#   'subject',
#   'noisy',
#   'chatter',
#   'patron',
#   'night',
#   'long',
#   'even',
#   'early_morne',
#   'charge',
#   'wifi',
#   'water',
#   'positive',
#   'supermarket',
#   'door',
#   'room',
#   'clean',
#   'spend',
#   'double',
#   'room',
#   'need'],
#  ['stay',
#   'property',
#   'night',
#   'big',
#   'mistake',
#   'old',
#   'place',
#   'dump',
#   'waste',
#   'money',
#   'bed',
#   'hard',
#   'nee',
#   'see',
#   'doctor',
#   'back',
#   'pain',
#   'trust',
#   'really',
#   'bad',
#   'old',
#   'towel',
#   'loud',
#   'night',
#   'bar',
#   'noise',
#   'stop',
#   'shower',
#   'old',
#   'sink',
#   'come',
#   'apart',
#   'old',
#   'pillow'],
#  ['month',
#   'work',
#   'leisure',
#   'stay',
#   'several',
#   'always',
#   'pleased',
#   'staff',
#   'service',
#   'accommodation',
#   'area',
#   'hotel',
#   'worst',
#   'stay',
#   'far',
#   'price_range',
#   'receptionist',
#   'accommodate',
#   'slightly',
#   'rude',
#   'definitely',
#   'friendly',
#   'personable',
#   'staff',
#   'act',
#   'know',
#   'time',
#   'stay',
#   'politely',
#   'ask',
#   'possible',
#   'change',
#   'room',
#   'first_night',
#   'room',
#   'locate',
#   'reception',
#   'desk',
#   'noisy',
#   'loud',
#   'people',
#   'check',
#   'day',
#   'night',
#   'could',
#   'sleep',
#   'first',
#   'room',
#   'comfortable'],
#  ['break',
#   'room',
#   'steal',
#   'cash',
#   'expensive',
#   'sunglass',
#   'staff',
#   'want',
#   'help',
#   'reluctant',
#   'inquire',
#   'staff',
#   'customer',
#   'incident',
#   'call',
#   'police',
#   'staff',
#   'actually',
#   'try',
#   'imply',
#   'lose',
#   'item',
#   'lock',
#   'door',
#   'fabricate',
#   'incident',
#   'lack',
#   'assistance',
#   'bad',
#   'invasion',
#   'privacy',
#   'particularly',
#   'young',
#   'solo',
#   'female',
#   'traveller',
#   'hotel',
#   'actually',
#   'large',
#   'house',
#   'room',
#   'rent',
#   'tell',
#   'else',
#   'room',
#   'staff',
#   'later',
#   'admit',
#   'owner',
#   'key',
#   'local',
#   'authority',
#   'tourism',
#   'police',
#   'helpful'],
#  ['room',
#   'clean',
#   'nice',
#   'however',
#   'walk',
#   'kitchen',
#   'get',
#   'shower',
#   'also',
#   'family',
#   'daily',
#   'live',
#   'believe',
#   'always',
#   'kitchen',
#   'also',
#   'reception',
#   'keep',
#   'people',
#   'child',
#   'talking_loudly',
#   'night',
#   'pm',
#   'family',
#   'feel',
#   'hotel',
#   'also',
#   'kitchen',
#   'fridge',
#   'clean',
#   'staff',
#   'owner',
#   'friendly',
#   'also',
#   'advertise',
#   'quite',
#   'distance',
#   'central',
#   'least',
#   'much',
#   'close',
#   'would',
#   'stay'],
#  ['good_location',
#   'check',
#   'clerk',
#   'show',
#   'old',
#   'rip',
#   'hand',
#   'towel',
#   'say',
#   'find',
#   'room',
#   'must',
#   'pay',
#   'rip',
#   'towel',
#   'charge',
#   'anyway',
#   'stay'],
#  ['stay',
#   'night',
#   'hotel',
#   'room',
#   'twin',
#   'bed',
#   'room',
#   'change',
#   'room',
#   'nice',
#   'little_bit',
#   'hard',
#   'regulate',
#   'shower',
#   'first_night',
#   'quiet',
#   'second_night',
#   'big',
#   'group',
#   'volunteer',
#   'stay',
#   'hotel',
#   'make',
#   'early_morne',
#   'location',
#   'hotel',
#   'good',
#   'central_park'],
#  ['really',
#   'clean',
#   'hotel',
#   'smell',
#   'bad',
#   'noisy',
#   'night',
#   'quite',
#   'close',
#   'guardian',
#   'friendly',
#   'price',
#   'possible',
#   'find',
#   'much_better',
#   'address'],
#  ['outside',
#   'town',
#   'mean',
#   'large',
#   'coach',
#   'stop',
#   'group',
#   'night',
#   'whole',
#   'quiet',
#   'sleep',
#   'town',
#   'also',
#   'cater',
#   'function',
#   'evening',
#   'disturbed',
#   'band',
#   'quite',
#   'late_night',
#   'add',
#   'tour',
#   'group',
#   'arrive',
#   'depart',
#   'nighttime',
#   'hour',
#   'voice',
#   'suitcase',
#   'bump',
#   'cobble',
#   'reverberate',
#   'complex',
#   'always',
#   'make',
#   'peaceful',
#   'sleep',
#   'look',
#   'ok',
#   'surface',
#   'tastefully',
#   'do',
#   'old',
#   'colonial',
#   'town',
#   'nice',
#   'area',
#   'lack',
#   'charm',
#   'personality',
#   'staff',
#   'particularly',
#   'friendly',
#   'room',
#   'rather',
#   'date',
#   'certainly',
#   'one',
#   'smell',
#   'damp',
#   'need',
#   'air',
#   'bed'],
#  ['end',
#   'awake',
#   'sound',
#   'room',
#   'alarm',
#   'noisy',
#   'guest',
#   'check',
#   'room',
#   'sound',
#   'control',
#   'poor',
#   'ventilation',
#   'get',
#   'quite',
#   'warm',
#   'vent',
#   'bed',
#   'squeaky',
#   'confortable',
#   'bathroom',
#   'horribly',
#   'decorate',
#   'overall',
#   'price',
#   'usd',
#   'sure',
#   'well',
#   'choice'],
#  ['lovely',
#   'grear',
#   'coffee',
#   'first',
#   'room',
#   'get',
#   'give',
#   'absolutely',
#   'stong',
#   'chemical',
#   'smell',
#   'imagine',
#   'floor',
#   'cleaner',
#   'ask',
#   'move',
#   'minute',
#   'make',
#   'nauseous',
#   'next',
#   'room',
#   'also',
#   'smell',
#   'old',
#   'run',
#   'road',
#   'noise',
#   'loud',
#   'mattress',
#   'mattress',
#   'protector',
#   'thin',
#   'fitted',
#   'sheet',
#   'go',
#   'straight',
#   'matress',
#   'gross',
#   'thumb'],
#  ['conveniently_locate',
#   'block',
#   'first',
#   'time',
#   'visit',
#   'select',
#   'mainly',
#   'basis',
#   'review',
#   'retrospect',
#   'may',
#   'safe',
#   'stay',
#   'night',
#   'give',
#   'location',
#   'search',
#   'alternative',
#   'meet',
#   'satisfaction',
#   'location',
#   'excellent',
#   'capable',
#   'walk',
#   'flight',
#   'steep',
#   'place',
#   'may',
#   'pose',
#   'challenge',
#   'help',
#   'assist',
#   'bag',
#   'maybe',
#   'much',
#   'early',
#   'check',
#   'next_morne',
#   'simply',
#   'furnish',
#   'hotel',
#   'many',
#   'similar',
#   'offering',
#   'thing',
#   'note',
#   'price',
#   'drop',
#   'considerably',
#   'made_reservation',
#   'line',
#   'several',
#   'month',
#   'ago',
#   'sometimes',
#   'inclined'],
#  ['right',
#   'market',
#   'grocery',
#   'store',
#   'employee',
#   'great',
#   'courteous',
#   'room',
#   'grand',
#   'special',
#   'hotel',
#   'old',
#   'look',
#   'room',
#   'hot',
#   'ask',
#   'second',
#   'fan',
#   'sauna',
#   'temperature',
#   'cool',
#   'deck',
#   'patio',
#   'cheap',
#   'charge',
#   'day',
#   'wifi',
#   'disappointment',
#   'hotel',
#   'include',
#   'level',
#   'dining',
#   'living_room',
#   'area',
#   'fountain',
#   'nice',
#   'chill',
#   'patio',
#   'nice',
#   'well',
#   'great_views',
#   'lot',
#   'seating'],
#  ['find',
#   'pet',
#   'friendly',
#   'hotel',
#   'blocks_main',
#   'able',
#   'visit',
#   'lot',
#   'landmark',
#   'small',
# ...
#   'could',
#   'clean',
#   'price',
#   'would',
#   'expect',
#   'bit',
#   'tip',
#   'go',
#   'pancake',
#   'breakfast'],
#  ['hotel',
#   'wet',
#   'room',
#   'could',
#   'smell',
#   'time',
#   'may',
#   'hard',
#   'sleep',
#   'room',
#   'hand',
#   'room',
#   'clean',
#   'receptionist',
#   'speak',
#   'good',
#   'willing',
#   'help',
#   'water',
#   'coffee',
#   'free',
#   'day',
#   'long'],
#  ['disappoint',
#   'lack',
#   'ambience',
#   'intermittent',
#   'music',
#   'table',
#   'decorate',
#   'normally',
#   'food',
#   'serve',
#   'room',
#   'temperature',
#   'quickly',
#   'go',
#   'cold',
#   'disappointing',
#   'experience',
#   'whole',
#   'entrance',
#   'area',
#   'need',
#   'revamp',
#   'previously',
#   'stay',
#   'years_ago',
#   'lovely',
#   'memory',
#   'choose',
#   'lunch',
#   'disappoint',
#   'find',
#   'aged',
#   'staff',
#   'welcome'],
#  ['stayed_night',
#   'staff_friendly',
#   'restaurant',
#   'great',
#   'breakfast',
#   'also',
#   'adjoin',
#   'bakery',
#   'location',
#   'hotel',
#   'area',
#   'unfortunately',
#   'bed',
#   'rather',
#   'hard',
#   'uncomfortable',
#   'room',
#   'hot',
#   'rather',
#   'noisy',
#   'could_hear',
#   'people',
#   'clearly',
#   'make',
#   'somewhat',
#   'difficult',
#   'sleep',
#   'time'],
#  ['night',
#   'budget',
#   'establishment',
#   'nice',
#   'proprietor',
#   'helpful',
#   'need',
#   'pro',
#   'relatively',
#   'quiet',
#   'first',
#   'room',
#   'see',
#   'review',
#   'convenient',
#   'excellent',
#   'breakfast',
#   'lunch_dinner',
#   'first',
#   'place',
#   'get',
#   'size',
#   'bed',
#   'con',
#   'room',
#   'bite',
#   'dark',
#   'well',
#   'use',
#   'bit',
#   'dusty',
#   'noisy',
#   'tenant',
#   'courtyard',
#   'late',
#   'loud',
#   'nice',
#   'aware',
#   'noisy',
#   'loud',
#   'singe',
#   'entertainment',
#   'weekend',
#   'room',
#   'back',
#   'wall',
#   'luckily',
#   'seem',
#   'stop',
#   'keep',
#   'second'],
#  ['couple',
#   'year',
#   'old',
#   'stay',
#   'room',
#   'small',
#   'clean',
#   'private_bathroom',
#   'also',
#   'clean',
#   'however',
#   'small',
#   'open',
#   'bathroom',
#   'hallway',
#   'high',
#   'wall',
#   'bar',
#   'roof',
#   'noisy',
#   'staff',
#   'shut',
#   'pm',
#   'hostel',
#   'quiet',
#   'night',
#   'staff',
#   'insist',
#   'hold',
#   'passport',
#   'ensure',
#   'payment',
#   'even_though',
#   'pay',
#   'cash',
#   'advance',
#   'claim',
#   'never',
#   'encounter',
#   'practice',
#   'would',
#   'good',
#   'place',
#   'young',
#   'traveler',
#   'look',
#   'socialize',
#   'party'],
#  ['noise',
#   'place',
#   'crazy',
#   'church_bell',
#   'ring',
#   'hotel',
#   'loudspeaker',
#   'play',
#   'mariachi',
#   'full',
#   'volume',
#   'pm',
#   'pm',
#   'traffic',
#   'definitely',
#   'pick',
#   'night',
#   'leave',
#   'torture',
#   'ear',
#   'violate',
#   'mind',
#   'advertisement',
#   'play',
#   'imagination',
#   'regard',
#   'place',
#   'reality',
#   'however',
#   'different'],
#  ['good',
#   'thing',
#   'come',
#   'stay',
#   'terrace',
#   'fellow',
#   'traveler',
#   'friend',
#   'meet',
#   'make',
#   'far',
#   'expensive',
#   'variety',
#   'hostel',
#   'option',
#   'would',
#   'also',
#   'poor',
#   'service',
#   'noisy',
#   'day',
#   'morning',
#   'view',
#   'volcano',
#   'terrace',
#   'save',
#   'grace',
#   'actually',
#   'enjoy',
#   'included_breakfast',
#   'include',
#   'beverage',
#   'drink',
#   'breakfast',
#   'price',
#   'pay',
#   'criminal',
#   'speak',
#   'criminal',
#   'friend',
#   'also',
#   'camera',
#   'steal',
#   'hostel',
#   'footage',
#   'make',
#   'available',
#   'push',
#   'several',
#   'day',
#   'even'],
#  ['arrive',
#   'little',
#   'cockroach',
#   'bed',
#   'bedroom',
#   'light',
#   'work',
#   'music',
#   'vibrate',
#   'wall',
#   'love',
#   'party',
#   'come_back',
#   'clean',
#   'room',
#   'able',
#   'go',
#   'sleep',
#   'want',
#   'say',
#   'lady',
#   'incredibly',
#   'helpful',
#   'apologetic',
#   'ask',
#   'help',
#   'find',
#   'new',
#   'hotel',
#   'pm',
#   'night',
#   'decide',
#   'enough',
#   'enough',
#   'call',
#   'around',
#   'get',
#   'somewhere',
#   'road',
#   'know',
#   'place',
#   'high',
#   'trip_advisor'],
#  ['place',
#   'student',
#   'interested',
#   'party',
#   'get',
#   'waste',
#   'meet',
#   'student',
#   'good',
#   'night',
#   'sleep',
#   'many',
#   'people',
#   'come',
#   'time',
#   'scream',
#   'loudly',
#   'hall',
#   'drunk',
#   'try',
#   'open',
#   'door',
#   'hostel',
#   'fall',
#   'apart',
#   'let',
#   'mention',
#   'hygiene',
#   'bathroom',
#   'shower',
#   'share',
#   'many',
#   'people',
#   'quality',
#   'mattress',
#   'feel',
#   'spring',
#   'back',
#   'sleep',
#   'tiny',
#   'cramped',
#   'room',
#   'synthetic',
#   'linen',
#   'leave',
#   'today'],
#  ['much',
#   'may',
#   'even',
#   'forget',
#   'believe',
#   'staff',
#   'incredibly',
#   'sweet',
#   'helpful',
#   'however',
#   'initial',
#   'love',
#   'place',
#   'soon',
#   'replace',
#   'incredible',
#   'annoyance',
#   'frustration',
#   'hammer',
#   'noise',
#   'intense',
#   'wake',
#   'hammer',
#   'sound',
#   'worker',
#   'top',
#   'room',
#   'also',
#   'mean',
#   'wake',
#   'sunrise',
#   'maybe',
#   'early_morne',
#   'would',
#   'problem',
#   'party',
#   'late',
#   'previous',
#   'night',
#   'initially',
#   'love',
#   'place',
#   'quite',
#   'disappointed',
#   'outcome',
#   'seek'],
#  ['reason',
#   'rate',
#   'rooftop',
#   'patio',
#   'view',
#   'fellow',
#   'traveller',
#   'would',
#   'congregate',
#   'bottle',
#   'wine',
#   'end',
#   'day',
#   'watch',
#   'sunset',
#   'volcano',
#   'room',
#   'nice',
#   'large',
#   'clean',
#   'bathroom',
#   'breakfast_buffet',
#   'bad',
#   'beef',
#   'slow',
#   'response',
#   'room',
#   'light',
#   'bulb',
#   'expire',
#   'take',
#   'hour',
#   'person',
#   'come',
#   'ladder',
#   'install',
#   'new',
#   'bulb',
#   'breakfast'],
#  ['stay',
#   'location',
#   'fantastic',
#   'room',
#   'basic',
#   'tv',
#   'simple',
#   'furniture',
#   'room',
#   'maintenance',
#   'issue',
#   'room',
#   'rather',
#   'small',
#   'clean',
#   'free_wifi',
#   'available',
#   'staff_member',
#   'great',
#   'attitude',
#   'manner',
#   'clearly',
#   'compensate',
#   'shortcoming',
#   'room',
#   'breakfast',
#   'available',
#   'understand',
#   'own',
#   'hotel',
#   'offer',
#   'great',
#   'breakfast',
#   'coffee',
#   'bite',
#   'put',
#   'rather',
#   'excessive',
#   'price',
#   'hotel',
#   'may',
#   'fact',
#   'stay',
#   'busy',
#   'day',
#   'year',
#   'charge',
#   'night',
#   'double',
#   'hotel',
#   'class',
#   'charge',
#   'hotel',
#   'good',
#   'option',
#   'basic'],
#  ['spend',
#   'actually',
#   'plane',
#   'hike',
#   'trek',
#   'volcano',
#   'night',
#   'really',
#   'need',
#   'sleep',
#   'trerrible',
#   'speak',
#   'guide',
#   'reception',
#   'many_time',
#   'continue',
#   'pm',
#   'party',
#   'hotel',
#   'day',
#   'take',
#   'also',
#   'disappointment',
#   'local',
#   'guide',
#   'never',
#   'look',
#   'behind',
#   'fast',
#   'group',
#   'lose',
#   'even',
#   'warn',
#   'guide',
#   'change',
#   'behavior',
#   'morning',
#   'wake',
#   'early',
#   'guide',
#   'sleep',
#   'chance',
#   'wake',
#   'time',
#   'try',
#   'wake'],
#  ['offer',
#   'tourist',
#   'traveler',
#   'enjoy',
#   'vice',
#   'night',
#   'life',
#   'location',
#   'pretty',
#   'great',
#   'couple_block',
#   'central_park',
#   'several',
#   'fun',
#   'option',
#   'night',
#   'club',
#   'block',
#   'even',
#   'want',
#   'stay',
#   'dining',
#   'drinking',
#   'dance',
#   'mainstream',
#   'music',
#   'last',
#   'night',
#   'around_pm',
#   'also',
#   'quaint',
#   'jacuzzi',
#   'back',
#   'guest',
#   'close',
#   'pm',
#   'wish',
#   'open',
#   'later',
#   'private',
#   'room',
#   'look',
#   'dank',
#   'hell',
#   'share',
#   'dorm',
#   'opinion',
#   'lack',
#   'provide',
#   'locker',
#   'bunk',
#   'absent',
#   'personal',
#   'light',
#   'electric',
#   'outlet',
#   'assign',
#   'dorm',
#   'bed',
#   'entire',
#   'room',
#   'electrical'],
#  ['hotel',
#   'use',
#   'lot',
#   'adventure',
#   'group',
#   'look',
#   'quiet',
#   'place',
#   'sleep',
#   'place',
#   'may',
#   'lucky',
#   'avoid',
#   'group',
#   'chance',
#   'group',
#   'quite',
#   'pleased',
#   'place',
#   'wifi_work',
#   'lobby',
#   'room',
#   'clean',
#   'room',
#   'shower',
#   'whole',
#   'hotel',
#   'decide',
#   'shower',
#   'time',
#   'concrete',
#   'helpful',
#   'staff',
#   'breakfast',
#   'ant',
#   'bathroom'],
#  ['stay',
#   'part',
#   'tour',
#   'organise',
#   'contact',
#   'staff',
#   'situate',
#   'hotel',
#   'basic',
#   'comfortable'],
#  ['decide',
#   'hotel',
#   'aviod',
#   'ruthless',
#   'drunk',
#   'loud',
#   'people',
#   'crowd',
#   'however',
#   'manage',
#   'find',
#   'room',
#   'noice',
#   'start',
#   'end',
#   'repeatetly',
#   'ask',
#   'noisy',
#   'guest',
#   'politely',
#   'quiet',
#   'respect',
#   'tell',
#   'guard',
#   'trouble',
#   'first',
#   'time',
#   'talk',
#   'work',
#   'second',
#   'time',
#   'neighbour',
#   'keep',
#   'talk',
#   'guard',
#   'even',
#   'come',
#   'room',
#   'nice',
#   'building',
#   'loud',
#   'neighbour',
#   'ruin',
#   'stay'],
#  ['room',
#   'lock',
#   'good',
#   'travel',
#   'desk',
#   'breakfast',
#   'bean',
#   'coffee',
#   'english_speake',
#   'staff',
#   'tell',
#   'website',
#   'also',
#   'can',
#   'pay',
#   'card',
#   'room',
#   'rather',
#   'grim',
#   'lock',
#   'window',
#   'together',
#   'muxh',
#   'overpriced'],
#  ['sure',
#   'hotel',
#   'describe',
#   'charming',
#   'maybe',
#   'old',
#   'gentleman',
#   'work',
#   'would',
#   'say',
#   'stop',
#   'grant',
#   'nice',
#   'want',
#   'cancel',
#   'second_night',
#   'originally_booke',
#   'positive',
#   'hotel',
#   'quiet',
#   'read',
#   'countless',
#   'review',
#   'place',
#   'seem',
#   'struggle',
#   'noise',
#   'hotel',
#   'least',
#   'quiet',
#   'room',
#   'tiny',
#   'dingy',
#   'dark',
#   'suspicious',
#   'shower',
#   'electrocute',
#   'husband',
#   'place',
#   'atmosphere',
#   'ever',
#   'kind',
#   'place',
#   'leave',
#   'feel',
#   'dirty',
#   'stay',
#   'leave',
#   'morning',
#   'comment',
#   'breakfast',
#   'want',
#   'leave',
#   'quickly',
#   'possible'],
#  ['recently',
#   'stay',
#   'route',
#   'hotel',
#   'strangely',
#   'arrange',
#   'pool_table',
#   'awkwardly',
#   'middle',
#   'way',
#   'check',
#   'suggestion',
#   'food',
#   'guest',
#   'step',
#   'offer',
#   'suggestion',
#   'american',
#   'owner',
#   'presumably',
#   'right',
#   'desk',
#   'remain',
#   'silent',
#   'try',
#   'communicate',
#   'staff',
#   'little',
#   'english',
#   'assist',
#   'stilted',
#   'communication',
#   'room',
#   'shared_bathroom',
#   'close',
#   'room',
#   'room',
#   'cramp',
#   'double_bed',
#   'room',
#   'bed',
#   'ceile',
#   'low',
#   'combination',
#   'bed',
#   'make',
#   'room',
#   'feel',
#   'claustrophobic',
#   'get',
#   'bed'],
#  ['anywhere',
#   'stay',
#   'expectation',
#   'heavily',
#   'influence',
#   'impression',
#   'review',
#   'place',
#   'expect',
#   'budget',
#   'hotel',
#   'locate',
#   'multiple',
#   'bar',
#   'nearby',
#   'think',
#   'people',
#   'would',
#   'ok',
#   'enough',
#   'book',
#   'know',
#   'bar',
#   'hotel',
#   'expect',
#   'hear',
#   'noise',
#   'night',
#   'choose',
#   'seem',
#   'optimally',
#   'locate',
#   'aim',
#   'location',
#   'block',
#   'right',
#   'centre',
#   'thing',
#   'say',
#   'realize',
#   'arrive',
#   'small',
#   'block',
#   'tiny',
#   'place',
#   'discount',
#   'extra',
#   'minute',
#   'walk',
#   'room',
#   'small',
#   'basic',
#   'little',
#   'dark',
#   'nice',
#   'touch'],
#  ['stay',
#   'wedding',
#   'really',
#   'want',
#   'place',
#   'sleep',
#   'unfortunately',
#   'room',
#   'close',
#   'street',
#   'bite',
#   'noisy',
#   'clean',
#   'centric',
#   'would',
#   'stay',
#   'option',
#   'would',
#   'look',
#   'first'],
#  ['stay',
#   'weekend',
#   'private',
#   'double',
#   'ok',
#   'quality',
#   'good',
#   'value_money',
#   'compare',
#   'similar',
#   'room',
#   'hostel',
#   'area',
#   'weekend',
#   'expect',
#   'bit',
#   'expect',
#   'terrace_bar',
#   'quite',
#   'noisy',
#   'day',
#   'room',
#   'right',
#   'bar',
#   'kitchen',
#   'could_hear',
#   'music',
#   'box',
#   'bottle',
#   'drag',
#   'around',
#   'midnight',
#   'need',
#   'power',
#   'nap',
#   'nasty',
#   'night',
#   'bus',
#   'want',
#   'sleep',
#   'lot',
#   'local',
#   'people',
#   'hostel',
#   'seem',
#   'visit',
#   'bar',
#   'tend',
#   'hog',
#   'upstairs',
#   'bathroom',
#   'whole',
#   'hostel',
#   'shower',
#   'little',
#   'tricky'],
#  ['mistaken',
#   'definitely',
#   'price',
#   'charge',
#   'much',
#   'say',
#   'thing',
#   'average',
#   'hotel',
#   'location',
#   'price',
#   'rest',
#   'room',
#   'bed',
#   'bathroom',
#   'say',
#   'even',
#   'hostel',
#   'even',
#   'room',
#   'locate',
#   'hotel',
#   'restaurant',
#   'noise',
#   'definitely',
#   'good',
#   'place'],
#  ['stayed_night',
#   'comfortable',
#   'room',
#   'bed',
#   'good',
#   'garden',
#   'look',
#   'good',
#   'comfortable',
#   'seat',
#   'plenty',
#   'insect',
#   'bite',
#   'average',
#   'breakfast',
#   'give',
#   'go',
#   'breakfast',
#   'place',
#   'well',
#   'away',
#   'block',
#   'km',
#   'quiet',
#   'street',
#   'want',
#   'walk',
#   'back',
#   'fact',
#   'place',
#   'lock',
#   'armed',
#   'tell',
#   'nee',
#   'know',
#   'security',
#   'concern'],
#  ['work',
#   'tourism',
#   'industry',
#   'stay',
#   'hotel',
#   'try',
#   'speak',
#   'people',
#   'manage',
#   'property',
#   'order',
#   'know',
#   'wrong',
#   'show',
#   'improve',
#   'unfortunately',
#   'case',
#   'hotel',
#   'bad',
#   'experience',
#   'ever',
#   'hotel',
#   'club',
#   'hotel',
#   'keep',
#   'room',
#   'small',
#   'picture',
#   'show',
#   'finish',
#   'thing',
#   'wake',
#   'sound',
#   'people',
#   'work',
#   'restaurant',
#   'prepare',
#   'breakfast',
#   'happen',
#   'stay',
#   'next_day',
#   'try',
#   'explain',
#   'case',
#   'agent',
#   'even',
#   'care',
#   'general',
#   'manager',
#   'never'],
#  ['small',
#   'establishment',
#   'kid',
#   'friendly',
#   'nice',
#   'playground',
#   'kid',
#   'loud',
#   'small',
#   'windows_open',
#   'get',
#   'air',
#   'hear',
#   'noise',
#   'courtyard',
#   'room',
#   'room',
#   'get',
#   'hot',
#   'beds_comfortable',
#   'room',
#   'big',
#   'small',
#   'bathroom',
#   'room',
#   'put',
#   'anywhere',
#   'time',
#   'take',
#   'breakfast_include',
#   'take',
#   'almost',
#   'hour',
#   'breakfast',
#   'many',
#   'day',
#   'thing',
#   'get',
#   'old',
#   'week',
#   'hotel',
#   'pretty',
#   'nice',
#   'many',
#   'place',
#   'stay',
#   'provide',
#   'well',
#   'value'],
#  ['book',
#   'book',
#   'double',
#   'triple',
#   'room',
#   'twin',
#   'switch',
#   'triple',
#   'tiny',
#   'room',
#   'double_bed',
#   'arrive',
#   'room',
#   'locate',
#   'back',
#   'next',
#   'laundry',
#   'quite',
#   'noisy',
#   'get',
#   'bad',
#   'start',
#   'also',
#   'room',
#   'available',
#   'outlet',
#   'phone',
#   'charging',
#   'different',
#   'circumstance',
#   'may',
#   'like',
#   'stay',
#   'serve',
#   'nice',
#   'breakfast',
#   'coffee',
#   'available',
#   'early',
#   'riser',
#   'well_situate',
#   'town'],
#  ['minute',
#   'walk',
#   'many',
#   'shops_restaurant',
#   'bar',
#   'pleasant',
#   'well',
#   'restore',
#   'traditional',
#   'hotel',
#   'good',
#   'room',
#   'queen',
#   'sized',
#   'bed',
#   'old',
#   'style',
#   'tv',
#   'roof',
#   'light',
#   'blind',
#   'wake',
#   'quite',
#   'early',
#   'light',
#   'problem',
#   'need',
#   'good',
#   'free',
#   'wi_fi',
#   'room',
#   'good',
#   'shower',
#   'shower',
#   'room',
#   'courtyard',
#   'supermarket'],
#  ['room',
#   'clean',
#   'building',
#   'nice',
#   'unfortunately',
#   'atmosphere',
#   'bit',
#   'cold',
#   'much',
#   'light',
#   'whole',
#   'building',
#   'staff',
#   'around',
#   'arrive',
#   'may',
#   'better_place'],
#  ['take',
#   'long',
#   'reach',
#   'downtown',
#   'advantage',
#   'hotel',
#   'small',
#   'bakery',
#   'nearby',
#   'min',
#   'walk',
#   'expensive',
#   'taste',
#   'good',
#   'convenient',
#   'next',
#   'hotel',
#   'pretty',
#   'good_location',
#   'shop',
#   'nearby',
#   'sick',
#   'travel',
#   'go',
#   'travel',
#   'day',
#   'take',
#   'rest',
#   'hotel',
#   'go',
#   'pastry',
#   'shop',
#   'lot',
#   'enough',
#   'power',
#   'walk',
#   'faraway',
#   'hotel',
#   'say',
#   'bread',
#   'save',
#   'life',
#   'old',
#   'town',
#   'beautiful',
#   'landscape',
#   'volcano',
#   'city'],
#  ['stay',
#   'part',
#   'adventure',
#   'tour',
#   'room',
#   'small',
#   'basic',
#   'hotel',
#   'great',
#   'hotel',
#   'shop',
#   'buy',
#   'drink',
#   'snack',
#   'nice',
#   'bakery',
#   'also',
#   'tasty',
#   'breakfast',
#   'nice',
#   'room',
#   'see',
#   'invite',
#   'hotel'],
#  ['place',
#   'type',
#   'place',
#   'get',
#   'pay',
#   'much',
#   'quite',
#   'simple',
#   'daunting',
#   'entrance',
#   'timber',
#   'door',
#   'open',
#   'nice',
#   'venue',
#   'hotel',
#   'different',
#   'room',
#   'quite_dark',
#   'eery',
#   'bathroom',
#   'basic',
#   'large',
#   'room',
#   'safe',
#   'air',
#   'conditioner',
#   'much',
#   'problem',
#   'quite',
#   'safe',
#   'high',
#   'brick',
#   'wall',
#   'solid',
#   'timber',
#   'gate',
#   'expose',
#   'concrete',
#   'brick',
#   'render',
#   'wall',
#   'act',
#   'good',
#   'insulator',
#   'keep',
#   'heat',
#   'invite',
#   'place',
#   'blink',
#   'door',
#   'convenience',
#   'store',
#   'purchase',
#   'snack',
#   'drink',
#   'smoke',
#   'next_door',
#   'side',
#   'find',
#   'nice',
#   'bakery',
#   'make',
#   'nice'],
#  ['fine',
#   'room',
#   'next',
#   'occupy',
#   'fart',
#   'could',
#   'smell',
#   'dorm',
#   'living',
#   'price',
#   'otherwise',
#   'clean',
#   'helpful',
#   'staff'],
#  ...]
